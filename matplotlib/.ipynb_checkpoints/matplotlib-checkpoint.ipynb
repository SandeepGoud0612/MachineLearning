# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# list of height
height = [150,160,165,185]
weight = [70, 80, 90, 100]
plt.plot(height, weight)

# %%
height = [150,160,165,185]
weight = [70, 80, 90, 100]
plt.title('Relationship between height and weight')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.plot(height, weight)

# %%
calories_burnt = [65, 75, 95, 99]
plt.plot(calories_burnt)
weight = [70, 80, 90, 100]
plt.plot(weight)
plt.legend(labels=['Calories Burnt', 'Weight'], loc='lower right')

# %%
plt.figure(figsize=(15,5))
plt.plot(calories_burnt, marker='o')
plt.plot(weight,'r--',marker='*')
plt.ylabel('Weight & Calories Burnt')
plt.xlabel('Persons')
plt.legend(labels=['Calories Burnt', 'Weight'], loc='lower right')
plt.xticks(ticks=[0,1,2,3], labels=['p1','p2','p3','p4'])
# Out:
# ([<matplotlib.axis.XTick at 0x1aceb798088>,
#   <matplotlib.axis.XTick at 0x1aceb79b708>,
#   <matplotlib.axis.XTick at 0x1aceb79b2c8>,
#   <matplotlib.axis.XTick at 0x1aceb7cd4c8>],
#  <a list of 4 Text xticklabel objects>)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(6,6))
ax[0,0].plot(calories_burnt,'go')
ax[0,1].plot(weight)
ax[0,0].set_title('Calories Burnt')
ax[0,1].set_title('Weight')
ax[0,0].set_xticks(ticks=[0,1,2,3])
ax[0,1].set_xticks(ticks=[0,1,2,3])
ax[0,0].set_xticklabels(labels=['p1','p2','p3','p4'])
ax[0,1].set_xticklabels(labels=['p1','p2','p3','p4'])
# Out:
# [Text(0, 0, 'p1'), Text(0, 0, 'p2'), Text(0, 0, 'p3'), Text(0, 0, 'p4')]

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,6), sharex=True, sharey=True)
ax[0].plot(calories_burnt,'g--',marker='o')
ax[1].plot(weight,'r',marker='*')
ax[0].set_title('Calories Burnt')
ax[1].set_title('Weight')
ax[0].set_xticks(ticks=[0,1,2,3])
ax[1].set_xticks(ticks=[0,1,2,3])
ax[0].set_xticklabels(labels=['p1','p2','p3','p4'])
ax[1].set_xticklabels(labels=['p1','p2','p3','p4'])
# Out:
# [Text(0, 0, 'p1'), Text(0, 0, 'p2'), Text(0, 0, 'p3'), Text(0, 0, 'p4')]

# %%
df = pd.read_csv('../dataset/csv/bigmart_data.csv')
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
price_by_item = df.groupby('Item_Type').Item_MRP.mean()[:6]
x = price_by_item.index.tolist()
y = price_by_item.values.tolist()
plt.figure(figsize=(20, 8))
plt.title('Mean price for each item type')
plt.xlabel('Item Type')
plt.ylabel('Mean Price')
plt.xticks(labels=x, ticks=np.arange(len(x)))
plt.plot(x, y, 'r--', marker='o')

# %%
np.arange(len(x))
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
sales_by_outlet_size = df.groupby('Outlet_Size').Item_Outlet_Sales.mean()
sales_by_outlet_size.sort_values(inplace=True)
x = sales_by_outlet_size.index.tolist()
y = sales_by_outlet_size.values.tolist()
plt.xlabel('Outlet Size')
plt.ylabel('Sales')
plt.title('Mean sales for each outlet type')
plt.xticks(labels=x, ticks=np.arange(len(x)))
plt.bar(x, y, color=['red', 'orange', 'magenta'])
sales_by_outlet_size
# Out:
# Outlet_Size
# Small     1912.149161
# High      2298.995256
# Medium    2681.603542
# Name: Item_Outlet_Sales, dtype: float64

# %%
plt.figure(figsize=(20, 8))
plt.title('Item MRP (price) distribution')
plt.xlabel('Item_MRP')
plt.ylabel('Frequency')
plt.hist(df['Item_MRP'], bins=100, color='lightblue')
# Out:
# (array([ 36.,  84., 121., 111.,  99.,  98., 116.,  97.,  82.,  79., 110.,
#          95.,  79.,  76.,  55.,   3.,   1.,  18.,  63.,  73.,  75.,  70.,
#          98., 106., 128.,  90., 125., 115., 115., 131., 117., 116., 119.,
#         140., 128., 124., 108., 127., 159., 110., 119.,  91.,  60.,  25.,
#           0.,  14., 116., 123., 131., 125., 122., 129., 113., 108., 108.,
#         106., 118.,  89.,  79., 126., 119., 123., 140., 119., 121., 122.,
#         117., 122., 104., 113., 144.,  50.,   1.,   3.,  29.,  39.,  63.,
#          57.,  47.,  47.,  52.,  59.,  60.,  68.,  64.,  67.,  45.,  37.,
#          57.,  48.,  41.,  53.,  58.,  48.,  71.,  68.,  62.,  68.,  82.,
#          36.]),
#  array([ 31.29    ,  33.645984,  36.001968,  38.357952,  40.713936,
#          43.06992 ,  45.425904,  47.781888,  50.137872,  52.493856,
#          54.84984 ,  57.205824,  59.561808,  61.917792,  64.273776,
#          66.62976 ,  68.985744,  71.341728,  73.697712,  76.053696,
#          78.40968 ,  80.765664,  83.121648,  85.477632,  87.833616,
#          90.1896  ,  92.545584,  94.901568,  97.257552,  99.613536,
#         101.96952 , 104.325504, 106.681488, 109.037472, 111.393456,
#         113.74944 , 116.105424, 118.461408, 120.817392, 123.173376,
#         125.52936 , 127.885344, 130.241328, 132.597312, 134.953296,
#         137.30928 , 139.665264, 142.021248, 144.377232, 146.733216,
#         149.0892  , 151.445184, 153.801168, 156.157152, 158.513136,
#         160.86912 , 163.225104, 165.581088, 167.937072, 170.293056,
#         172.64904 , 175.005024, 177.361008, 179.716992, 182.072976,
#         184.42896 , 186.784944, 189.140928, 191.496912, 193.852896,
#         196.20888 , 198.564864, 200.920848, 203.276832, 205.632816,
#         207.9888  , 210.344784, 212.700768, 215.056752, 217.412736,
#         219.76872 , 222.124704, 224.480688, 226.836672, 229.192656,
#         231.54864 , 233.904624, 236.260608, 238.616592, 240.972576,
#         243.32856 , 245.684544, 248.040528, 250.396512, 252.752496,
#         255.10848 , 257.464464, 259.820448, 262.176432, 264.532416,
#         266.8884  ]),
#  <a list of 100 Patch objects>)

# %%
data = df[['Item_Outlet_Sales']]
red_diamond = dict(markerfacecolor='r', marker='D')
plt.title('Item Sales Distribution')
plt.boxplot(data.values, labels=['Item Sales'], flierprops=red_diamond)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1acf823a448>,
#   <matplotlib.lines.Line2D at 0x1acf8232e08>],
#  'caps': [<matplotlib.lines.Line2D at 0x1acf823af48>,
#   <matplotlib.lines.Line2D at 0x1acf823ab48>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1acf8232c08>],
#  'medians': [<matplotlib.lines.Line2D at 0x1acf823ea48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1acf823ef88>],
#  'means': []}

# %%
data = df['Item_MRP']
red_diamond = dict(markerfacecolor='r', marker='D')
plt.boxplot(data.values, labels=['Item MRP (Price)'], flierprops=red_diamond)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1acf7c68488>,
#   <matplotlib.lines.Line2D at 0x1acf7c68508>],
#  'caps': [<matplotlib.lines.Line2D at 0x1acf7c68b48>,
#   <matplotlib.lines.Line2D at 0x1acf7c77248>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1acf7c69308>],
#  'medians': [<matplotlib.lines.Line2D at 0x1acf7c77348>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1acf7c74f48>],
#  'means': []}

# %%
data = df[['Item_MRP']]
plt.xlabel('Item MRP')
plt.violinplot(data.values)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1acf80d1d88>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1acf7bf8548>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1acf80d1f48>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1acf7e28248>}

# %%
data.describe()
# Out:
# count    8523.000000
# mean      140.992782
# std        62.275067
# min        31.290000
# 25%        93.826500
# 50%       143.012800
# 75%       185.643700
# max       266.888400
# Name: Item_MRP, dtype: float64

# %%
x=[1,2,3,4,5]
x=pd.DataFrame(x)
x.describe()
# Out:
#               0
# count  5.000000
# mean   3.000000
# std    1.581139
# min    1.000000
# 25%    2.000000
# 50%    3.000000
# 75%    4.000000
# max    5.000000

# %%
plt.xlabel('Item_Weight')
plt.ylabel('Item_Visibility')
plt.scatter(df['Item_Weight'][:200], df['Item_Visibility'][:200])

# %%
plt.xlabel('Item_MRP')
plt.ylabel('Item_Outlet_Sales')
plt.title('Item Outlet Sales vs Item MRP (price)')
plt.scatter(df['Item_MRP'][:100], df['Item_Outlet_Sales'][:100], s=df['Item_Visibility'][:100]*1000, c='red')
