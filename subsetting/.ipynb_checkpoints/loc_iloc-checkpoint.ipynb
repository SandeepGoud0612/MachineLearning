# %%
import pandas as pd

# %%
data = pd.read_csv('../dataset/uk-500.csv')

# %%
data.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
data.shape
# Out:
# (500, 11)

# %%
data.tail()
# Out:
#     first_name last_name                    company_name             address  \
# 495      Avery      Veit      Plaza Gourmet Delicatessen  9166 Devon St #905
# 496       Reid   Euresti            Fitzgerald, Edward J        70 Foster St
# 497  Charlette  Brenning              Furey & Associates     714 Fonthill Rd
# 498  Celestina     Keeny        Bfg Federal Credit Union         9 Milton St
# 499         Mi    Richan  Nelson Wright Haworth Golf Crs     6 Norwood Grove
#
#                                city           county    postal        phone1  \
# 495  Knightsbridge and Belgravia Wa   Greater London  SW1W 8JY  01748-625058
# 496        Inverness Ness-Side Ward         Highland   IV2 6WT  01916-963261
# 497                Darton West Ward  South Yorkshire   S75 5EJ  01888-152110
# 498                Consett North ED    County Durham   DH8 5LP  01877-379681
# 499               Tanworth-in-Arden     Warwickshire   B94 5RZ  01451-785624
#
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
data.columns
# Out:
# Index(['first_name', 'last_name', 'company_name', 'address', 'city', 'county',
#        'postal', 'phone1', 'phone2', 'email', 'web'],
#       dtype='object')

# %%
len(data.columns)
# Out:
# 11

# %%
import random
data['id'] = [random.randint(0, 1000) for i in range(data.shape[0])]

# %%
data.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
data.iloc[0]
# Out:
# first_name                                   Aleshia
# last_name                                 Tomkiewicz
# company_name                 Alan D Rosenburg Cpa Pc
# address                                 14 Taylor St
# city                               St. Stephens Ward
# county                                          Kent
# postal                                       CT2 7PP
# phone1                                  01835-703597
# phone2                                  01944-369967
# email                        atomkiewicz@hotmail.com
# web             http://www.alandrosenburgcpapc.co.uk
# id                                               216
# Name: 0, dtype: object

# %%
data.iloc[2]
# Out:
# first_name                                France
# last_name                                Andrade
# company_name                 Elliott, John W Esq
# address                             8 Moor Place
# city              East Southbourne and Tuckton W
# county                               Bournemouth
# postal                                   BH6 3BE
# phone1                              01347-368222
# phone2                              01935-821636
# email                 france.andrade@hotmail.com
# web             http://www.elliottjohnwesq.co.uk
# id                                           703
# Name: 2, dtype: object

# %%
data.iloc[-1]
# Out:
# first_name                                               Mi
# last_name                                            Richan
# company_name                 Nelson Wright Haworth Golf Crs
# address                                     6 Norwood Grove
# city                                      Tanworth-in-Arden
# county                                         Warwickshire
# postal                                              B94 5RZ
# phone1                                         01451-785624
# phone2                                         01202-738406
# email                                        mi@hotmail.com
# web             http://www.nelsonwrighthaworthgolfcrs.co.uk
# id                                                      458
# Name: 499, dtype: object

# %%
data.iloc[:,0]
# Out:
# 0        Aleshia
# 1           Evan
# 2         France
# 3        Ulysses
# 4         Tyisha
#          ...
# 495        Avery
# 496         Reid
# 497    Charlette
# 498    Celestina
# 499           Mi
# Name: first_name, Length: 500, dtype: object

# %%
data.iloc[0,:]
# Out:
# first_name                                   Aleshia
# last_name                                 Tomkiewicz
# company_name                 Alan D Rosenburg Cpa Pc
# address                                 14 Taylor St
# city                               St. Stephens Ward
# county                                          Kent
# postal                                       CT2 7PP
# phone1                                  01835-703597
# phone2                                  01944-369967
# email                        atomkiewicz@hotmail.com
# web             http://www.alandrosenburgcpapc.co.uk
# id                                               216
# Name: 0, dtype: object

# %%
data.iloc[:,-1]
# Out:
# 0      216
# 1      891
# 2      703
# 3      882
# 4      275
#       ...
# 495    412
# 496    660
# 497    924
# 498    766
# 499    458
# Name: id, Length: 500, dtype: int64

# %%
data.iloc[0:5]
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
data.iloc[:, 0:2]
# Out:
#     first_name   last_name
# 0      Aleshia  Tomkiewicz
# 1         Evan   Zigomalas
# 2       France     Andrade
# 3      Ulysses   Mcwalters
# 4       Tyisha      Veness
# ..         ...         ...
# 495      Avery        Veit
# 496       Reid     Euresti
# 497  Charlette    Brenning
# 498  Celestina       Keeny
# 499         Mi      Richan
#
# [500 rows x 2 columns]

# %%
data.iloc[[0,3,6,24],[0,5,6]]
# Out:
#    first_name        county    postal
# 0     Aleshia          Kent   CT2 7PP
# 3     Ulysses  Lincolnshire  DN36 5RP
# 6        Marg   Southampton  SO14 3TY
# 24       Tess   West Sussex  PO19 1RH

# %%
data.iloc[1,1]
# Out:
# 'Zigomalas'

# %%
data.iloc[[0]]
# Out:
#            first_name             company_name       address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc  14 Taylor St
#
#                          city county   postal        phone1        phone2  \
# last_name
# Tomkiewicz  St. Stephens Ward   Kent  CT2 7PP  01835-703597  01944-369967
#
#                               email                                   web   id
# last_name
# Tomkiewicz  atomkiewicz@hotmail.com  http://www.alandrosenburgcpapc.co.uk  216

# %%
data.iloc[0:5, 1:5]
# Out:
#                        company_name            address  \
# last_name
# Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# Zigomalas        Cap Gemini America        5 Binney St
# Andrade         Elliott, John W Esq       8 Moor Place
# Mcwalters            Mcmahan, Ben L      505 Exeter Rd
# Veness               Champagne Room  5396 Forth Street
#
#                                       city           county
# last_name
# Tomkiewicz               St. Stephens Ward             Kent
# Zigomalas                       Abbey Ward  Buckinghamshire
# Andrade     East Southbourne and Tuckton W      Bournemouth
# Mcwalters               Hawerby cum Beesby     Lincolnshire
# Veness          Greets Green and Lyng Ward    West Midlands

# %%
data.iloc[[1],[1]]
# Out:
#                  company_name
# last_name
# Zigomalas  Cap Gemini America

# %%
data.set_index('last_name', inplace=True)

# %%
data.head()
# Out:
#            first_name             company_name            address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc       14 Taylor St
# Zigomalas        Evan       Cap Gemini America        5 Binney St
# Andrade        France      Elliott, John W Esq       8 Moor Place
# Mcwalters     Ulysses           Mcmahan, Ben L      505 Exeter Rd
# Veness         Tyisha           Champagne Room  5396 Forth Street
#
#                                       city           county    postal  \
# last_name
# Tomkiewicz               St. Stephens Ward             Kent   CT2 7PP
# Zigomalas                       Abbey Ward  Buckinghamshire  HP11 2AX
# Andrade     East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# Mcwalters               Hawerby cum Beesby     Lincolnshire  DN36 5RP
# Veness          Greets Green and Lyng Ward    West Midlands   B70 9DT
#
#                   phone1        phone2                       email  \
# last_name
# ...

# %%
data.loc['Andrade']
# Out:
# first_name                                France
# company_name                 Elliott, John W Esq
# address                             8 Moor Place
# city              East Southbourne and Tuckton W
# county                               Bournemouth
# postal                                   BH6 3BE
# phone1                              01347-368222
# phone2                              01935-821636
# email                 france.andrade@hotmail.com
# web             http://www.elliottjohnwesq.co.uk
# id                                           703
# Name: Andrade, dtype: object

# %%
data.loc[['Andrade', 'Veness']]
# Out:
#           first_name         company_name            address  \
# last_name
# Andrade       France  Elliott, John W Esq       8 Moor Place
# Veness        Tyisha       Champagne Room  5396 Forth Street
#
#                                      city         county   postal  \
# last_name
# Andrade    East Southbourne and Tuckton W    Bournemouth  BH6 3BE
# Veness         Greets Green and Lyng Ward  West Midlands  B70 9DT
#
#                  phone1        phone2                       email  \
# last_name
# Andrade    01347-368222  01935-821636  france.andrade@hotmail.com
# Veness     01547-429341  01290-367248   tyisha.veness@hotmail.com
#
#                                         web   id
# last_name
# Andrade    http://www.elliottjohnwesq.co.uk  703
# Veness       http://www.champagneroom.co.uk  275

# %%
data.loc[['Andrade', 'Veness'], ['first_name', 'address', 'city']]
# Out:
#           first_name            address                            city
# last_name
# Andrade       France       8 Moor Place  East Southbourne and Tuckton W
# Veness        Tyisha  5396 Forth Street      Greets Green and Lyng Ward

# %%
data.loc[['Andrade', 'Veness'], 'first_name':'city']
# Out:
#           first_name         company_name            address  \
# last_name
# Andrade       France  Elliott, John W Esq       8 Moor Place
# Veness        Tyisha       Champagne Room  5396 Forth Street
#
#                                      city
# last_name
# Andrade    East Southbourne and Tuckton W
# Veness         Greets Green and Lyng Ward

# %%
data.loc['Andrade':'Veness', ['first_name', 'address', 'city']]
# Out:
#           first_name            address                            city
# last_name
# Andrade       France       8 Moor Place  East Southbourne and Tuckton W
# Mcwalters    Ulysses      505 Exeter Rd              Hawerby cum Beesby
# Veness        Tyisha  5396 Forth Street      Greets Green and Lyng Ward

# %%
data.loc[data['first_name'] == 'Erasmo']
# Out:
#           first_name        company_name             address  \
# last_name
# Talentino     Erasmo  Active Air Systems       3 Garden Lane
# Gath          Erasmo            Pan Optx       860 Rokeby St
# Rhea          Erasmo    Martin Morrissey  5544 Sutherland St
#
#                        city           county    postal        phone1  \
# last_name
# Talentino  Darton West Ward  South Yorkshire   S75 5JY  01492-454455
# Gath            Sunningdale        Berkshire   SL5 0AZ  01445-796544
# Rhea               Mortehoe            Devon  EX34 7DQ  01507-386397
#
#                  phone2                         email  \
# last_name
# Talentino  01304-185373  erasmo.talentino@hotmail.com
# Gath       01650-307192             egath@hotmail.com
# Rhea       01899-316385       erasmo_rhea@hotmail.com
#
#                                          web   id
# last_name
# Talentino  http://www.activeairsystems.co.uk  929
# Gath                http://www.panoptx.co.uk  443
# ...

# %%
data.loc[data['first_name'] == 'Erasmo', ['company_name', 'email', 'phone1']]
# Out:
#                  company_name                         email        phone1
# last_name
# Talentino  Active Air Systems  erasmo.talentino@hotmail.com  01492-454455
# Gath                 Pan Optx             egath@hotmail.com  01445-796544
# Rhea         Martin Morrissey       erasmo_rhea@hotmail.com  01507-386397

# %%
s1 = data.loc[data['first_name'] == 'Antonio', 'email']

# %%
s1.shape
# Out:
# (3,)

# %%
s1
# Out:
# last_name
# Villamarin       antonio.villamarin@gmail.com
# Glasford      antonio_glasford@glasford.co.uk
# Heilig               antonio.heilig@gmail.com
# Name: email, dtype: object

# %%
s1.head()
# Out:
# last_name
# Villamarin       antonio.villamarin@gmail.com
# Glasford      antonio_glasford@glasford.co.uk
# Heilig               antonio.heilig@gmail.com
# Name: email, dtype: object

# %%
data.loc[data['first_name'] == 'Antonio', 'city':'email']
# Out:
#                                       city         county    postal  \
# last_name
# Villamarin  Little Parndon and Hare Street  Hertfordshire  CM20 2HT
# Glasford                    Gaer Community        Newport  NP20 3DE
# Heilig                            Ipplepen          Devon  TQ12 5LL
#
#                   phone1        phone2                            email
# last_name
# Villamarin  01559-403415  01388-777812     antonio.villamarin@gmail.com
# Glasford    01463-409090  01242-318420  antonio_glasford@glasford.co.uk
# Heilig      01324-171614  01442-946357         antonio.heilig@gmail.com

# %%
data.loc[data['email'].str.endswith('hotmail.com')]
# Out:
#            first_name                    company_name                 address  \
# last_name
# Tomkiewicz    Aleshia         Alan D Rosenburg Cpa Pc            14 Taylor St
# Andrade        France             Elliott, John W Esq            8 Moor Place
# Mcwalters     Ulysses                  Mcmahan, Ben L           505 Exeter Rd
# Veness         Tyisha                  Champagne Room       5396 Forth Street
# Grasmick         Marg   Wrangle Hill Auto Auct & Slvg        7457 Cowl St #70
# ...               ...                             ...                     ...
# Gaucher        Sophia               T C E Systems Inc  88 Upper Harrington St
# Ausdemore      Rosita               Jurdem, Scott Esq    8 Heathfield St #657
# Stancil          Huey                   Lindner Funds             275 Peel Sq
# Fiorino        Elbert            Donald, G Nelson Esq  726 Westmoreland Place
# Richan             Mi  Nelson Wright Haworth Golf Crs         6 Norwood Grove
#
# ...

# %%
data.loc[data['first_name'].isin(['France','Tyisha','Eric'])]
# Out:
#           first_name             company_name            address  \
# last_name
# Andrade       France      Elliott, John W Esq       8 Moor Place
# Veness        Tyisha           Champagne Room  5396 Forth Street
# Rampy           Eric  Thompson, Michael C Esq       9472 Lind St
#
#                                      city            county    postal  \
# last_name
# Andrade    East Southbourne and Tuckton W       Bournemouth   BH6 3BE
# Veness         Greets Green and Lyng Ward     West Midlands   B70 9DT
# Rampy                          Desborough  Northamptonshire  NN14 2GH
#
#                  phone1        phone2                       email  \
# last_name
# Andrade    01347-368222  01935-821636  france.andrade@hotmail.com
# Veness     01547-429341  01290-367248   tyisha.veness@hotmail.com
# Rampy      01969-886290  01545-817375          erampy@rampy.co.uk
#
#                                             web   id
# last_name
# ...

# %%
data.loc[data['email'].str.endswith('gmail.com') & (data['first_name'] == 'Antonio')]
# Out:
#            first_name          company_name                address  \
# last_name
# Villamarin    Antonio      Combs Sheetmetal  353 Standish St #8264
# Heilig        Antonio  Radisson Suite Hotel         35 Elton St #3
#
#                                       city         county    postal  \
# last_name
# Villamarin  Little Parndon and Hare Street  Hertfordshire  CM20 2HT
# Heilig                            Ipplepen          Devon  TQ12 5LL
#
#                   phone1        phone2                         email  \
# last_name
# Villamarin  01559-403415  01388-777812  antonio.villamarin@gmail.com
# Heilig      01324-171614  01442-946357      antonio.heilig@gmail.com
#
#                                             web   id
# last_name
# Villamarin     http://www.combssheetmetal.co.uk   76
# Heilig      http://www.radissonsuitehotel.co.uk  215

# %%
data.loc[(data['id'] > 100) & (data['id'] < 200)].shape
# Out:
# (38, 11)
