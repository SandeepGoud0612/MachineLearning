# %%
import pandas as pd

# %%
data = pd.read_csv('../dataset/csv/big_mart_sales.csv')

# %%
data.head()
# Out:
#            first_name             company_name            address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc       14 Taylor St
# Zigomalas        Evan       Cap Gemini America        5 Binney St
# Andrade        France      Elliott, John W Esq       8 Moor Place
# Mcwalters     Ulysses           Mcmahan, Ben L      505 Exeter Rd
# Veness         Tyisha           Champagne Room  5396 Forth Street
#
#                                       city           county    postal  \
# last_name
# Tomkiewicz               St. Stephens Ward             Kent   CT2 7PP
# Zigomalas                       Abbey Ward  Buckinghamshire  HP11 2AX
# Andrade     East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# Mcwalters               Hawerby cum Beesby     Lincolnshire  DN36 5RP
# Veness          Greets Green and Lyng Ward    West Midlands   B70 9DT
#
#                   phone1        phone2                       email  \
# last_name
# ...

# %%
data.head(10)
# Out:
#            first_name                   company_name               address  \
# last_name
# Tomkiewicz    Aleshia        Alan D Rosenburg Cpa Pc          14 Taylor St
# Zigomalas        Evan             Cap Gemini America           5 Binney St
# Andrade        France            Elliott, John W Esq          8 Moor Place
# Mcwalters     Ulysses                 Mcmahan, Ben L         505 Exeter Rd
# Veness         Tyisha                 Champagne Room     5396 Forth Street
# Rampy            Eric        Thompson, Michael C Esq          9472 Lind St
# Grasmick         Marg  Wrangle Hill Auto Auct & Slvg      7457 Cowl St #70
# Hisaw         Laquita          In Communications Inc  20 Gloucester Pl #96
# Manzella         Lura                Bizerba Usa Inc      929 Augustine St
# Klapec         Yuette                      Max Video  45 Bradfield St #166
#
#                                       city                 county    postal  \
# last_name
# ...

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data = pd.read_csv('../dataset/csv/big_mart_sales.csv')

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data.loc[data['Item_Weight'].isna() == True, 'Item_Weight'] = data['Item_Weight'].mean()

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data['Item_Weight'].mean()
# Out:
# 12.857645184136409

# %%
data['Item_Weight'].median()
# Out:
# 12.857645184136183

# %%
data['Item_Weight'].mode()
# Out:
# 0    12.857645
# dtype: float64

# %%
data['Outlet_Size'].mode()
# Out:
# 0    Medium
# dtype: object

# %%
data.loc[data['Outlet_Size'].isna() == True, 'Outlet_Size'] = 'Medium'

# %%
data.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
data.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
data['Outlet_Size'].fillna('Medium', inplace=True)

# %%
data.Outlet_Size.values_counts
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-d5da23019a54> in <module>
# ----> 1 data.Outlet_Size.values_counts
#
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'values_counts'

# %%
data.Outlet_Size.value_counts()
# Out:
# Medium    5203
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
data.Item_Fat_Content.value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
mapping = {
    'Low Fat': 'LF',
    'Regular': 'R',
    'reg': 'R',
    'LF': 'LF'
}

# %%
data.Item_Fat_Content = data.Item_Fat_Content.map(mapping)

# %%
data.Item_Fat_Content.value_counts()
# Out:
# LF    5517
# R     3006
# Name: Item_Fat_Content, dtype: int64

# %%
data.Item_Fat_Content.isna().sum()
# Out:
# 112

# %%
data.Item_Fat_Content.fillna('LF', inplace=True)

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30               LF         0.016047
# 1           DRC01         5.92                R         0.019278
# 2           FDN15        17.50               LF         0.016760
# 3           FDX07        19.20                R         0.000000
# 4           NCD19         8.93               LF         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data['Item_MRP_USD'] = data.Item_MRP.apply(lambda x: x/74)

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30               LF         0.016047
# 1           DRC01         5.92                R         0.019278
# 2           FDN15        17.50               LF         0.016760
# 3           FDX07        19.20                R         0.000000
# 4           NCD19         8.93               LF         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
pd.get_dummies(data)
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Outlet_Sales  Item_MRP_USD  Item_Identifier_DRA12  \
# ...

# %%
data.set_index('Item_Type', inplace=True)

# %%
data.head()
# Out:
#                       Item_Identifier  Item_Weight Item_Fat_Content  \
# Item_Type
# Dairy                           FDA15         9.30          Low Fat
# Soft Drinks                     DRC01         5.92          Regular
# Meat                            FDN15        17.50          Low Fat
# Fruits and Vegetables           FDX07        19.20          Regular
# Household                       NCD19         8.93          Low Fat
#
#                        Item_Visibility  Item_MRP Outlet_Identifier  \
# Item_Type
# Dairy                         0.016047  249.8092            OUT049
# Soft Drinks                   0.019278   48.2692            OUT018
# Meat                          0.016760  141.6180            OUT049
# Fruits and Vegetables         0.000000  182.0950            OUT010
# Household                     0.000000   53.8614            OUT013
#
#                        Outlet_Establishment_Year Outlet_Size  \
# Item_Type
# ...

# %%
data.loc['Dairy']
# Out:
#           Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Type
# Dairy               FDA15        9.300          Low Fat         0.016047
# Dairy               FDA03       18.500          Regular         0.045464
# Dairy               FDU02       13.350          Low Fat         0.102492
# Dairy               FDE51        5.925          Regular         0.161467
# Dairy               FDV38       19.250          Low Fat         0.170349
# ...                   ...          ...              ...              ...
# Dairy               FDC39        7.405          Low Fat         0.159165
# Dairy               FDS26       20.350          Low Fat         0.089975
# Dairy               FDV50       14.300          Low Fat         0.123071
# Dairy               FDY50        5.800          Low Fat         0.130931
# Dairy               FDR26       20.700          Low Fat         0.042801
#
#            Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
data.loc[['Dairy'], ['Item_Identifier', 'Item_Fat_Content']]
# Out:
#           Item_Identifier Item_Fat_Content
# Item_Type
# Dairy               FDA15          Low Fat
# Dairy               FDA03          Regular
# Dairy               FDU02          Low Fat
# Dairy               FDE51          Regular
# Dairy               FDV38          Low Fat
# ...                   ...              ...
# Dairy               FDC39          Low Fat
# Dairy               FDS26          Low Fat
# Dairy               FDV50          Low Fat
# Dairy               FDY50          Low Fat
# Dairy               FDR26          Low Fat
#
# [682 rows x 2 columns]

# %%
data.iloc[1:10]
# Out:
#                       Item_Identifier  Item_Weight Item_Fat_Content  \
# Item_Type
# Soft Drinks                     DRC01        5.920          Regular
# Meat                            FDN15       17.500          Low Fat
# Fruits and Vegetables           FDX07       19.200          Regular
# Household                       NCD19        8.930          Low Fat
# Baking Goods                    FDP36       10.395          Regular
# Snack Foods                     FDO10       13.650          Regular
# Snack Foods                     FDP10          NaN          Low Fat
# Frozen Foods                    FDH17       16.200          Regular
# Frozen Foods                    FDU28       19.200          Regular
#
#                        Item_Visibility  Item_MRP Outlet_Identifier  \
# Item_Type
# Soft Drinks                   0.019278   48.2692            OUT018
# Meat                          0.016760  141.6180            OUT049
# ...

# %%
data.iloc[1:10]
# Out:
#                       Item_Identifier  Item_Weight Item_Fat_Content  \
# Item_Type
# Soft Drinks                     DRC01        5.920          Regular
# Meat                            FDN15       17.500          Low Fat
# Fruits and Vegetables           FDX07       19.200          Regular
# Household                       NCD19        8.930          Low Fat
# Baking Goods                    FDP36       10.395          Regular
# Snack Foods                     FDO10       13.650          Regular
# Snack Foods                     FDP10          NaN          Low Fat
# Frozen Foods                    FDH17       16.200          Regular
# Frozen Foods                    FDU28       19.200          Regular
#
#                        Item_Visibility  Item_MRP Outlet_Identifier  \
# Item_Type
# Soft Drinks                   0.019278   48.2692            OUT018
# Meat                          0.016760  141.6180            OUT049
# ...

# %%
data.iloc[1:10,1:5]
# Out:
#                        Item_Weight Item_Fat_Content  Item_Visibility  Item_MRP
# Item_Type
# Soft Drinks                  5.920          Regular         0.019278   48.2692
# Meat                        17.500          Low Fat         0.016760  141.6180
# Fruits and Vegetables       19.200          Regular         0.000000  182.0950
# Household                    8.930          Low Fat         0.000000   53.8614
# Baking Goods                10.395          Regular         0.000000   51.4008
# Snack Foods                 13.650          Regular         0.012741   57.6588
# Snack Foods                    NaN          Low Fat         0.127470  107.7622
# Frozen Foods                16.200          Regular         0.016687   96.9726
# Frozen Foods                19.200          Regular         0.094450  187.8214

# %%
data.iloc[[1:5]]
# Out:
#   File "<ipython-input-22-83e652123474>", line 1
#     data.iloc[[1:5]]
#                 ^
# SyntaxError: invalid syntax

# %%
data[1:5]
# Out:
#                       Item_Identifier  Item_Weight Item_Fat_Content  \
# Item_Type
# Soft Drinks                     DRC01         5.92          Regular
# Meat                            FDN15        17.50          Low Fat
# Fruits and Vegetables           FDX07        19.20          Regular
# Household                       NCD19         8.93          Low Fat
#
#                        Item_Visibility  Item_MRP Outlet_Identifier  \
# Item_Type
# Soft Drinks                   0.019278   48.2692            OUT018
# Meat                          0.016760  141.6180            OUT049
# Fruits and Vegetables         0.000000  182.0950            OUT010
# Household                     0.000000   53.8614            OUT013
#
#                        Outlet_Establishment_Year Outlet_Size  \
# Item_Type
# Soft Drinks                                 2009      Medium
# Meat                                        1999      Medium
# Fruits and Vegetables                       1998         NaN
# ...

# %%
data.iloc[1:5]
# Out:
#                       Item_Identifier  Item_Weight Item_Fat_Content  \
# Item_Type
# Soft Drinks                     DRC01         5.92          Regular
# Meat                            FDN15        17.50          Low Fat
# Fruits and Vegetables           FDX07        19.20          Regular
# Household                       NCD19         8.93          Low Fat
#
#                        Item_Visibility  Item_MRP Outlet_Identifier  \
# Item_Type
# Soft Drinks                   0.019278   48.2692            OUT018
# Meat                          0.016760  141.6180            OUT049
# Fruits and Vegetables         0.000000  182.0950            OUT010
# Household                     0.000000   53.8614            OUT013
#
#                        Outlet_Establishment_Year Outlet_Size  \
# Item_Type
# Soft Drinks                                 2009      Medium
# Meat                                        1999      Medium
# Fruits and Vegetables                       1998         NaN
# ...

# %%
data['Meat']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Meat'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-839f0311c222> in <module>
# ----> 1 data['Meat']
#
# ...

# %%
data.head()
# Out:
#                       Item_Identifier  Item_Weight Item_Fat_Content  \
# Item_Type
# Dairy                           FDA15         9.30          Low Fat
# Soft Drinks                     DRC01         5.92          Regular
# Meat                            FDN15        17.50          Low Fat
# Fruits and Vegetables           FDX07        19.20          Regular
# Household                       NCD19         8.93          Low Fat
#
#                        Item_Visibility  Item_MRP Outlet_Identifier  \
# Item_Type
# Dairy                         0.016047  249.8092            OUT049
# Soft Drinks                   0.019278   48.2692            OUT018
# Meat                          0.016760  141.6180            OUT049
# Fruits and Vegetables         0.000000  182.0950            OUT010
# Household                     0.000000   53.8614            OUT013
#
#                        Outlet_Establishment_Year Outlet_Size  \
# Item_Type
# ...

# %%
data.loc['Dairy']
# Out:
#           Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Type
# Dairy               FDA15        9.300          Low Fat         0.016047
# Dairy               FDA03       18.500          Regular         0.045464
# Dairy               FDU02       13.350          Low Fat         0.102492
# Dairy               FDE51        5.925          Regular         0.161467
# Dairy               FDV38       19.250          Low Fat         0.170349
# ...                   ...          ...              ...              ...
# Dairy               FDC39        7.405          Low Fat         0.159165
# Dairy               FDS26       20.350          Low Fat         0.089975
# Dairy               FDV50       14.300          Low Fat         0.123071
# Dairy               FDY50        5.800          Low Fat         0.130931
# Dairy               FDR26       20.700          Low Fat         0.042801
#
#            Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
data[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-80a4aab09c73> in <module>
# ----> 1 data[0]
#
# ...

# %%
data[0:4]
# Out:
#                       Item_Identifier  Item_Weight Item_Fat_Content  \
# Item_Type
# Dairy                           FDA15         9.30          Low Fat
# Soft Drinks                     DRC01         5.92          Regular
# Meat                            FDN15        17.50          Low Fat
# Fruits and Vegetables           FDX07        19.20          Regular
#
#                        Item_Visibility  Item_MRP Outlet_Identifier  \
# Item_Type
# Dairy                         0.016047  249.8092            OUT049
# Soft Drinks                   0.019278   48.2692            OUT018
# Meat                          0.016760  141.6180            OUT049
# Fruits and Vegetables         0.000000  182.0950            OUT010
#
#                        Outlet_Establishment_Year Outlet_Size  \
# Item_Type
# Dairy                                       1999      Medium
# Soft Drinks                                 2009      Medium
# Meat                                        1999      Medium
# ...

# %%
data[[1:4]]
# Out:
#   File "<ipython-input-32-8522fcfac40e>", line 1
#     data[[1:4]]
#            ^
# SyntaxError: invalid syntax

# %%
data['Item_Identifier'][1:3]
# Out:
# Item_Type
# Soft Drinks    DRC01
# Meat           FDN15
# Name: Item_Identifier, dtype: object

# %%
sample_df = pd.DataFrame({
    'gender': ['M','F','M','M','F'],
    'grade' : ['A','A','B','B','A'],
    'marks' : [22, 21, 12, 14, 20],
    'id' : ['A101', 'A102', 'A103', 'A104', 'A105']
})

# %%
sample_df.head()
# Out:
#   gender grade  marks    id
# 0      M     A     22  A101
# 1      F     A     21  A102
# 2      M     B     12  A103
# 3      M     B     14  A104
# 4      F     A     20  A105

# %%
sample_df = sample_df.sort_values(by=['marks'])

# %%
sample_df
# Out:
#   gender grade  marks    id
# 2      M     B     12  A103
# 3      M     B     14  A104
# 4      F     A     20  A105
# 1      F     A     21  A102
# 0      M     A     22  A101

# %%
sample_df.loc[2:4]
# Out:
#   gender grade  marks    id
# 2      M     B     12  A103
# 3      M     B     14  A104
# 4      F     A     20  A105

# %%
sample_df.iloc[2:4]
# Out:
#   gender grade  marks    id
# 4      F     A     20  A105
# 1      F     A     21  A102

# %%
sample_df[2:4]
# Out:
#   gender grade  marks    id
# 4      F     A     20  A105
# 1      F     A     21  A102

# %%
import pandas as pd
import random
 
# read the data from the downloaded CSV file.
data = pd.read_csv('../dataset/uk-500.csv')
# set a numeric id for use as an index for examples.
data['id'] = [random.randint(0,1000) for x in range(data.shape[0])]
 
data.head(5)
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
data.shape
# Out:
# (500, 12)

# %%
data.set_index("last_name", inplace=True)
data.head()
# Out:
#            first_name             company_name            address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc       14 Taylor St
# Zigomalas        Evan       Cap Gemini America        5 Binney St
# Andrade        France      Elliott, John W Esq       8 Moor Place
# Mcwalters     Ulysses           Mcmahan, Ben L      505 Exeter Rd
# Veness         Tyisha           Champagne Room  5396 Forth Street
#
#                                       city           county    postal  \
# last_name
# Tomkiewicz               St. Stephens Ward             Kent   CT2 7PP
# Zigomalas                       Abbey Ward  Buckinghamshire  HP11 2AX
# Andrade     East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# Mcwalters               Hawerby cum Beesby     Lincolnshire  DN36 5RP
# Veness          Greets Green and Lyng Ward    West Midlands   B70 9DT
#
#                   phone1        phone2                       email  \
# last_name
# ...

# %%
data.loc[['Andrade', 'Veness'], 'city':'email']
# Out:
#                                      city         county   postal  \
# last_name
# Andrade    East Southbourne and Tuckton W    Bournemouth  BH6 3BE
# Veness         Greets Green and Lyng Ward  West Midlands  B70 9DT
#
#                  phone1        phone2                       email
# last_name
# Andrade    01347-368222  01935-821636  france.andrade@hotmail.com
# Veness     01547-429341  01290-367248   tyisha.veness@hotmail.com

# %%
data.loc['Andrade':'Veness', ['first_name', 'address', 'city']]
# Out:
#           first_name            address                            city
# last_name
# Andrade       France       8 Moor Place  East Southbourne and Tuckton W
# Mcwalters    Ulysses      505 Exeter Rd              Hawerby cum Beesby
# Veness        Tyisha  5396 Forth Street      Greets Green and Lyng Ward
