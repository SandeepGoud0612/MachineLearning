# %%
import pandas as pd

# %%
data = pd.read_csv('../dataset/csv/big_mart_sales.csv')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data[1:4]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800

# %%
data[data.Outlet_Establishment_Year == 1987]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 14             FDF32       16.350          Low Fat         0.068024
# 20             FDN22       18.850          Regular         0.138190
# 27             DRJ59       11.650          low fat         0.019356
# ...              ...          ...              ...              ...
# 8462           FDQ31        5.785          Regular         0.053802
# 8466           FDJ32       10.695          Low Fat         0.057744
# 8484           DRJ49        6.865          Low Fat         0.000000
# 8512           FDR26       20.700          Low Fat         0.042801
# 8518           FDF22        6.865          Low Fat         0.056783
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 4                 Household   53.8614            OUT013
# ...

# %%
data.loc[data.Outlet_Establishment_Year == 1987]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 14             FDF32       16.350          Low Fat         0.068024
# 20             FDN22       18.850          Regular         0.138190
# 27             DRJ59       11.650          low fat         0.019356
# ...              ...          ...              ...              ...
# 8462           FDQ31        5.785          Regular         0.053802
# 8466           FDJ32       10.695          Low Fat         0.057744
# 8484           DRJ49        6.865          Low Fat         0.000000
# 8512           FDR26       20.700          Low Fat         0.042801
# 8518           FDF22        6.865          Low Fat         0.056783
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 4                 Household   53.8614            OUT013
# ...

# %%
data.loc[(data.Outlet_Establishment_Year == 2009) & (data.Outlet_Size == 'Medium'), 'Item_Visibility']
# Out:
# 1       0.019278
# 5       0.000000
# 16      0.008596
# 31      0.080829
# 32      0.000000
#           ...
# 8506    0.084676
# 8511    0.026980
# 8515    0.021518
# 8516    0.118661
# 8521    0.145221
# Name: Item_Visibility, Length: 928, dtype: float64

# %%
data.iloc[data.Outlet_Establishment_Year == 1987]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-9-e71e21435a68> in <module>
# ----> 1 data.iloc[data.Outlet_Establishment_Year == 1987]
#
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2121
#    2122         if com.is_bool_indexer(key):
# -> 2123             self._validate_key(key, axis)
#    2124             return self._getbool_axis(key, axis=axis)
#    2125
#
# ...

# %%
data.loc[data.Outlet_Establishment_Year.isin([1987, 1988, 1999])]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 10             FDY07       11.800          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8475           NCS17       18.600          Low Fat         0.080627
# 8479           FDL10        8.395          Low Fat         0.039554
# 8484           DRJ49        6.865          Low Fat         0.000000
# 8512           FDR26       20.700          Low Fat         0.042801
# 8518           FDF22        6.865          Low Fat         0.056783
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.loc[data.Outlet_Establishment_Year.isin([1987, 1988, 1999]), ['Outlet_Establishment_Year', 'Item_MRP', 'Item_Identifier']]
# Out:
#       Outlet_Establishment_Year  Item_MRP Item_Identifier
# 0                          1999  249.8092           FDA15
# 2                          1999  141.6180           FDN15
# 4                          1987   53.8614           NCD19
# 6                          1987   57.6588           FDO10
# 10                         1999   45.5402           FDY07
# ...                         ...       ...             ...
# 8475                       1999   92.5436           NCS17
# 8479                       1999   99.1042           FDL10
# 8484                       1987  129.9652           DRJ49
# 8512                       1987  178.3028           FDR26
# 8518                       1987  214.5218           FDF22
#
# [1862 rows x 3 columns]

# %%
data.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
data.select_dtypes('int64')
# Out:
#       Outlet_Establishment_Year
# 0                          1999
# 1                          2009
# 2                          1999
# 3                          1998
# 4                          1987
# ...                         ...
# 8518                       1987
# 8519                       2002
# 8520                       2004
# 8521                       2009
# 8522                       1997
#
# [8523 rows x 1 columns]

# %%
data.select_dtypes('object')
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# ...              ...              ...                    ...
# 8518           FDF22          Low Fat            Snack Foods
# 8519           FDS36          Regular           Baking Goods
# 8520           NCJ29          Low Fat     Health and Hygiene
# 8521           FDN46          Regular            Snack Foods
# 8522           DRG01          Low Fat            Soft Drinks
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 1  Supermarket Type1
# 1               OUT018      Medium               Tier 3  Supermarket Type2
# ...

# %%
data.select_dtypes('float64')
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# 0           9.300         0.016047  249.8092          3735.1380
# 1           5.920         0.019278   48.2692           443.4228
# 2          17.500         0.016760  141.6180          2097.2700
# 3          19.200         0.000000  182.0950           732.3800
# 4           8.930         0.000000   53.8614           994.7052
# ...           ...              ...       ...                ...
# 8518        6.865         0.056783  214.5218          2778.3834
# 8519        8.380         0.046982  108.1570           549.2850
# 8520       10.600         0.035186   85.1224          1193.1136
# 8521        7.210         0.145221  103.1332          1845.5976
# 8522       14.800         0.044878   75.4670           765.6700
#
# [8523 rows x 4 columns]
