# %%
import pandas as pd

# %%
data = pd.read_csv('dataset/csv/big_mart_sales.csv')

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %%
data.shape
# Out:
# (8523, 12)

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
data.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b24701f77fd2> in <module>
# ----> 1 head(5)
#
# NameError: name 'head' is not defined

# %%
data.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
import random
random_list = [random.randint(1, 8523) for i in range(8523)]

# %%
random_list = random.sample(range(1,8524), 8523)
random_list
# Out:
# [4379,
#  1186,
#  7376,
#  93,
#  2598,
#  880,
#  4052,
#  6761,
#  5194,
#  6710,
#  8503,
#  6337,
#  2855,
#  7137,
#  8031,
#  5932,
#  7098,
#  4528,
#  7678,
#  6269,
#  4345,
#  1665,
#  4099,
#  6796,
#  657,
#  6036,
#  6738,
#  5305,
#  6313,
#  1058,
#  2083,
#  7312,
#  2847,
#  6836,
#  6950,
#  2628,
#  7330,
#  3830,
#  2165,
#  8180,
#  1330,
#  7660,
#  2417,
#  7649,
#  6196,
#  3930,
#  1043,
#  2586,
#  3434,
#  7277,
#  4683,
#  6486,
#  3796,
#  4401,
#  466,
#  4048,
#  6504,
#  827,
#  6993,
#  6892,
#  4074,
#  1370,
#  2178,
#  7818,
#  5962,
#  4909,
#  8094,
#  5622,
#  7416,
#  3746,
#  6899,
#  5778,
#  3804,
#  1461,
#  4069,
#  4833,
#  4516,
#  1511,
#  7985,
#  7746,
#  3006,
#  2378,
#  692,
#  6664,
#  2647,
#  1380,
#  1941,
#  3543,
#  226,
#  2292,
#  4089,
#  108,
#  6503,
#  2175,
#  568,
#  2537,
#  3885,
#  983,
#  3737,
#  2956,
#  4976,
#  1146,
#  1030,
#  1737,
#  247,
#  1689,
#  8463,
#  6883,
#  6882,
#  5449,
#  4337,
#  5752,
# ...

# %%
random_list
# Out:
# [3420,
#  5572,
#  5399,
#  8445,
#  6586,
#  1871,
#  5720,
#  4015,
#  2535,
#  6570,
#  1629,
#  4340,
#  4716,
#  8148,
#  5630,
#  2377,
#  5551,
#  5213,
#  2012,
#  1858,
#  4652,
#  5220,
#  4985,
#  7135,
#  5026,
#  4062,
#  7177,
#  1969,
#  7786,
#  3838,
#  5882,
#  7716,
#  2536,
#  6568,
#  533,
#  2480,
#  2585,
#  2671,
#  620,
#  3900,
#  351,
#  8103,
#  4773,
#  6916,
#  1995,
#  876,
#  5694,
#  4073,
#  5152,
#  412,
#  7843,
#  3025,
#  1356,
#  5559,
#  5074,
#  514,
#  2826,
#  822,
#  6202,
#  1254,
#  6702,
#  5342,
#  2906,
#  1457,
#  6933,
#  8209,
#  4520,
#  182,
#  4453,
#  3347,
#  5634,
#  2045,
#  5108,
#  3869,
#  2112,
#  4874,
#  5936,
#  3129,
#  3868,
#  7996,
#  4069,
#  3286,
#  1306,
#  6847,
#  7421,
#  7890,
#  3296,
#  7027,
#  3551,
#  2228,
#  5500,
#  357,
#  4976,
#  8139,
#  4894,
#  6419,
#  782,
#  3286,
#  6724,
#  4070,
#  7653,
#  6421,
#  2346,
#  8034,
#  3482,
#  1983,
#  826,
#  1533,
#  7009,
#  5203,
#  1704,
#  4185,
# ...

# %%
data.index = random_list

# %%
data.index
# Out:
# Int64Index([ 413, 4939, 3017, 1078, 2643, 4807, 6229, 3598, 8260, 3126,
#             ...
#              284, 5233, 4145, 4885, 8283, 2186, 2042, 7039, 3764,    1],
#            dtype='int64', length=8523)

# %%
data.head(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 413            FDA15        9.300          Low Fat         0.016047
# 4939           DRC01        5.920          Regular         0.019278
# 3017           FDN15       17.500          Low Fat         0.016760
# 1078           FDX07       19.200          Regular         0.000000
# 2643           NCD19        8.930          Low Fat         0.000000
# 4807           FDP36       10.395          Regular         0.000000
# 6229           FDO10       13.650          Regular         0.012741
# 3598           FDP10          NaN          Low Fat         0.127470
# 8260           FDH17       16.200          Regular         0.016687
# 3126           FDU28       19.200          Regular         0.094450
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 413                   Dairy  249.8092            OUT049
# 4939            Soft Drinks   48.2692            OUT018
# ...

# %%
data.set_index('Outlet_Establishment_Year', drop=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-f078eb7c5311> in <module>
# ----> 1 data.set_index('Outlet_Establishment_Year', drop=True, inplace=True)
#
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Outlet_Establishment_Year'] are in the columns"

# %%
data.head(10)
# Out:
#                           Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Establishment_Year
# 1999                                FDA15        9.300          Low Fat
# 2009                                DRC01        5.920          Regular
# 1999                                FDN15       17.500          Low Fat
# 1998                                FDX07       19.200          Regular
# 1987                                NCD19        8.930          Low Fat
# 2009                                FDP36       10.395          Regular
# 1987                                FDO10       13.650          Regular
# 1985                                FDP10          NaN          Low Fat
# 2002                                FDH17       16.200          Regular
# 2007                                FDU28       19.200          Regular
#
#                            Item_Visibility              Item_Type  Item_MRP  \
# Outlet_Establishment_Year
# ...

# %%
data.reset_index(inplace=True)

# %%
data.head(5)
# Out:
#    Outlet_Establishment_Year Item_Identifier  Item_Weight Item_Fat_Content  \
# 0                       1999           FDA15         9.30          Low Fat
# 1                       2009           DRC01         5.92          Regular
# 2                       1999           FDN15        17.50          Low Fat
# 3                       1998           FDX07        19.20          Regular
# 4                       1987           NCD19         8.93          Low Fat
#
#    Item_Visibility              Item_Type  Item_MRP Outlet_Identifier  \
# 0         0.016047                  Dairy  249.8092            OUT049
# 1         0.019278            Soft Drinks   48.2692            OUT018
# 2         0.016760                   Meat  141.6180            OUT049
# 3         0.000000  Fruits and Vegetables  182.0950            OUT010
# 4         0.000000              Household   53.8614            OUT013
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
data.set_index('Item_Identifier', drop=True, inplace=True)

# %%
data.head(5)
# Out:
#                  Outlet_Establishment_Year  Item_Weight Item_Fat_Content  \
# Item_Identifier
# FDA15                                 1999         9.30          Low Fat
# DRC01                                 2009         5.92          Regular
# FDN15                                 1999        17.50          Low Fat
# FDX07                                 1998        19.20          Regular
# NCD19                                 1987         8.93          Low Fat
#
#                  Item_Visibility              Item_Type  Item_MRP  \
# Item_Identifier
# FDA15                   0.016047                  Dairy  249.8092
# DRC01                   0.019278            Soft Drinks   48.2692
# FDN15                   0.016760                   Meat  141.6180
# FDX07                   0.000000  Fruits and Vegetables  182.0950
# NCD19                   0.000000              Household   53.8614
#
#                 Outlet_Identifier Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...

# %%
data.index
# Out:
# Index(['FDA15', 'DRC01', 'FDN15', 'FDX07', 'NCD19', 'FDP36', 'FDO10', 'FDP10',
#        'FDH17', 'FDU28',
#        ...
#        'FDH31', 'FDA01', 'FDH24', 'NCJ19', 'FDF53', 'FDF22', 'FDS36', 'NCJ29',
#        'FDN46', 'DRG01'],
#       dtype='object', name='Item_Identifier', length=8523)

# %%
data.loc['FDA15']
# Out:
#                  Outlet_Establishment_Year  Item_Weight Item_Fat_Content  \
# Item_Identifier
# FDA15                                 1999          9.3          Low Fat
# FDA15                                 2002          9.3          Low Fat
# FDA15                                 2004          9.3          Low Fat
# FDA15                                 2009          9.3          Low Fat
# FDA15                                 1998          9.3          Low Fat
# FDA15                                 1987          9.3          Low Fat
# FDA15                                 1985          NaN          Low Fat
# FDA15                                 2007          9.3               LF
#
#                  Item_Visibility Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                   0.016047     Dairy  249.8092            OUT049
# FDA15                   0.016055     Dairy  250.2092            OUT045
# ...

# %%
data.reset_index(inplace=True)

# %%
data.head(5)
# Out:
#   Item_Identifier  Outlet_Establishment_Year  Item_Weight Item_Fat_Content  \
# 0           FDA15                       1999         9.30          Low Fat
# 1           DRC01                       2009         5.92          Regular
# 2           FDN15                       1999        17.50          Low Fat
# 3           FDX07                       1998        19.20          Regular
# 4           NCD19                       1987         8.93          Low Fat
#
#    Item_Visibility              Item_Type  Item_MRP Outlet_Identifier  \
# 0         0.016047                  Dairy  249.8092            OUT049
# 1         0.019278            Soft Drinks   48.2692            OUT018
# 2         0.016760                   Meat  141.6180            OUT049
# 3         0.000000  Fruits and Vegetables  182.0950            OUT010
# 4         0.000000              Household   53.8614            OUT013
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
data[data['Item_Type'] == 'Dairy'].shape
# Out:
# (682, 12)

# %%
data[data['Item_Type'] == 'Dairy']
# Out:
#      Item_Identifier  Outlet_Establishment_Year  Item_Weight Item_Fat_Content  \
# 0              FDA15                       1999        9.300          Low Fat
# 11             FDA03                       1997       18.500          Regular
# 19             FDU02                       2004       13.350          Low Fat
# 28             FDE51                       1998        5.925          Regular
# 30             FDV38                       1998       19.250          Low Fat
# ...              ...                        ...          ...              ...
# 8424           FDC39                       2004        7.405          Low Fat
# 8447           FDS26                       2007       20.350          Low Fat
# 8448           FDV50                       2009       14.300          Low Fat
# 8457           FDY50                       2004        5.800          Low Fat
# 8512           FDR26                       1987       20.700          Low Fat
#
# ...

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.0.1'

# %%
df = pd.read_csv('../dataset/csv/big_mart_sales.csv')

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-412feca855b9> in <module>
# ----> 1 df.rows
#
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df[df['Item_Type'] == 'Dairy']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 0              FDA15        9.300          Low Fat         0.016047     Dairy
# 11             FDA03       18.500          Regular         0.045464     Dairy
# 19             FDU02       13.350          Low Fat         0.102492     Dairy
# 28             FDE51        5.925          Regular         0.161467     Dairy
# 30             FDV38       19.250          Low Fat         0.170349     Dairy
# ...              ...          ...              ...              ...       ...
# 8424           FDC39        7.405          Low Fat         0.159165     Dairy
# 8447           FDS26       20.350          Low Fat         0.089975     Dairy
# 8448           FDV50       14.300          Low Fat         0.123071     Dairy
# 8457           FDY50        5.800          Low Fat         0.130931     Dairy
# 8512           FDR26       20.700          Low Fat         0.042801     Dairy
#
# ...

# %%
df.set_index('Outlet_Establishment_Year')
# Out:
#                           Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Establishment_Year
# 1999                                FDA15        9.300          Low Fat
# 2009                                DRC01        5.920          Regular
# 1999                                FDN15       17.500          Low Fat
# 1998                                FDX07       19.200          Regular
# 1987                                NCD19        8.930          Low Fat
# ...                                   ...          ...              ...
# 1987                                FDF22        6.865          Low Fat
# 2002                                FDS36        8.380          Regular
# 2004                                NCJ29       10.600          Low Fat
# 2009                                FDN46        7.210          Regular
# 1997                                DRG01       14.800          Low Fat
#
# ...

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.set_index('Item_Type', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-694d9b548bcb> in <module>
# ----> 1 df.set_index('Item_Type', inplace=True)
#
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Item_Type'] are in the columns"

# %%
df
# Out:
#                       Item_Identifier  Item_Weight Item_Fat_Content  \
# Item_Type
# Dairy                           FDA15        9.300          Low Fat
# Soft Drinks                     DRC01        5.920          Regular
# Meat                            FDN15       17.500          Low Fat
# Fruits and Vegetables           FDX07       19.200          Regular
# Household                       NCD19        8.930          Low Fat
# ...                               ...          ...              ...
# Snack Foods                     FDF22        6.865          Low Fat
# Baking Goods                    FDS36        8.380          Regular
# Health and Hygiene              NCJ29       10.600          Low Fat
# Snack Foods                     FDN46        7.210          Regular
# Soft Drinks                     DRG01       14.800          Low Fat
#
#                        Item_Visibility  Item_MRP Outlet_Identifier  \
# Item_Type
# ...

# %%
df.reset_index()
# Out:
#                   Item_Type Item_Identifier  Item_Weight Item_Fat_Content  \
# 0                     Dairy           FDA15        9.300          Low Fat
# 1               Soft Drinks           DRC01        5.920          Regular
# 2                      Meat           FDN15       17.500          Low Fat
# 3     Fruits and Vegetables           FDX07       19.200          Regular
# 4                 Household           NCD19        8.930          Low Fat
# ...                     ...             ...          ...              ...
# 8518            Snack Foods           FDF22        6.865          Low Fat
# 8519           Baking Goods           FDS36        8.380          Regular
# 8520     Health and Hygiene           NCJ29       10.600          Low Fat
# 8521            Snack Foods           FDN46        7.210          Regular
# 8522            Soft Drinks           DRG01       14.800          Low Fat
#
#       Item_Visibility  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df.set_index('Item_Weight', drop=True)
# Out:
#             Item_Identifier Item_Fat_Content  Item_Visibility  Item_MRP  \
# Item_Weight
# 9.300                 FDA15          Low Fat         0.016047  249.8092
# 5.920                 DRC01          Regular         0.019278   48.2692
# 17.500                FDN15          Low Fat         0.016760  141.6180
# 19.200                FDX07          Regular         0.000000  182.0950
# 8.930                 NCD19          Low Fat         0.000000   53.8614
# ...                     ...              ...              ...       ...
# 6.865                 FDF22          Low Fat         0.056783  214.5218
# 8.380                 FDS36          Regular         0.046982  108.1570
# 10.600                NCJ29          Low Fat         0.035186   85.1224
# 7.210                 FDN46          Regular         0.145221  103.1332
# 14.800                DRG01          Low Fat         0.044878   75.4670
#
#             Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# Item_Weight
# ...

# %%
df
# Out:
#                       Item_Identifier  Item_Weight Item_Fat_Content  \
# Item_Type
# Dairy                           FDA15        9.300          Low Fat
# Soft Drinks                     DRC01        5.920          Regular
# Meat                            FDN15       17.500          Low Fat
# Fruits and Vegetables           FDX07       19.200          Regular
# Household                       NCD19        8.930          Low Fat
# ...                               ...          ...              ...
# Snack Foods                     FDF22        6.865          Low Fat
# Baking Goods                    FDS36        8.380          Regular
# Health and Hygiene              NCJ29       10.600          Low Fat
# Snack Foods                     FDN46        7.210          Regular
# Soft Drinks                     DRG01       14.800          Low Fat
#
#                        Item_Visibility  Item_MRP Outlet_Identifier  \
# Item_Type
# ...

# %%
df.set_index('Item_Visibility', inplace=True)

# %%
df
# Out:
#                 Item_Identifier  Item_Weight Item_Fat_Content  Item_MRP  \
# Item_Visibility
# 0.016047                  FDA15        9.300          Low Fat  249.8092
# 0.019278                  DRC01        5.920          Regular   48.2692
# 0.016760                  FDN15       17.500          Low Fat  141.6180
# 0.000000                  FDX07       19.200          Regular  182.0950
# 0.000000                  NCD19        8.930          Low Fat   53.8614
# ...                         ...          ...              ...       ...
# 0.056783                  FDF22        6.865          Low Fat  214.5218
# 0.046982                  FDS36        8.380          Regular  108.1570
# 0.035186                  NCJ29       10.600          Low Fat   85.1224
# 0.145221                  FDN46        7.210          Regular  103.1332
# 0.044878                  DRG01       14.800          Low Fat   75.4670
#
#                 Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_MRP',
#        'Outlet_Identifier', 'Outlet_Establishment_Year', 'Outlet_Size',
#        'Outlet_Location_Type', 'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')
