# %%
import pandas as pd

# %%
data = pd.read_csv('../dataset/csv/big_mart_sales.csv')

# %%
data.shape
# Out:
# (8523, 12)

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
data.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
data.tail(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8513           FDH31       12.000          Regular         0.020407
# 8514           FDA01       15.000          Regular         0.054489
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8513                Meat   99.9042            OUT035
# 8514              Canned   57.5904            OUT045
# 8515        Baking Goods  157.5288            OUT018
# ...

# %%
data[10:15]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 10           FDY07        11.80          Low Fat         0.000000
# 11           FDA03        18.50          Regular         0.045464
# 12           FDX32        15.10          Regular         0.100014
# 13           FDS46        17.60          Regular         0.047257
# 14           FDF32        16.35          Low Fat         0.068024
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 10  Fruits and Vegetables   45.5402            OUT049
# 11                  Dairy  144.1102            OUT046
# 12  Fruits and Vegetables  145.4786            OUT049
# 13            Snack Foods  119.6782            OUT046
# 14  Fruits and Vegetables  196.4426            OUT013
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 10                       1999      Medium               Tier 1
# 11                       1997       Small               Tier 1
# ...

# %%
data.iloc[10:15]
# Out:
#     Item_Weight Item_Identifier Item_Fat_Content  Item_Visibility  \
# 10        11.80           FDY07          Low Fat         0.000000
# 11        18.50           FDA03          Regular         0.045464
# 12        15.10           FDX32          Regular         0.100014
# 13        17.60           FDS46          Regular         0.047257
# 14        16.35           FDF32          Low Fat         0.068024
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 10  Fruits and Vegetables   45.5402            OUT049
# 11                  Dairy  144.1102            OUT046
# 12  Fruits and Vegetables  145.4786            OUT049
# 13            Snack Foods  119.6782            OUT046
# 14  Fruits and Vegetables  196.4426            OUT013
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 10                       1999      Medium               Tier 1
# 11                       1997       Small               Tier 1
# ...

# %%
data.iloc[[1:10]]
# Out:
#   File "<ipython-input-36-53309e8573a5>", line 1
#     data.iloc[[1:10]]
#                 ^
# SyntaxError: invalid syntax

# %%
data.iloc[[1]]
# Out:
#    Item_Weight Item_Identifier Item_Fat_Content  Item_Visibility    Item_Type  \
# 1         5.92           DRC01          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 1               Tier 3  Supermarket Type2           443.4228

# %%
data.iloc[[1,3,5,6,7]]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1           DRC01        5.920          Regular         0.019278
# 3           FDX07       19.200          Regular         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 1            Soft Drinks   48.2692            OUT018
# 3  Fruits and Vegetables  182.0950            OUT010
# 5           Baking Goods   51.4008            OUT018
# 6            Snack Foods   57.6588            OUT013
# 7            Snack Foods  107.7622            OUT027
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1                       2009      Medium               Tier 3
# 3                       1998         NaN               Tier 3
# ...

# %%
data.iloc[[3,6,7,8,34], [1,2,3]]
# Out:
#     Item_Weight Item_Fat_Content  Item_Visibility
# 3         19.20          Regular         0.000000
# 6         13.65          Regular         0.012741
# 7           NaN          Low Fat         0.127470
# 8         16.20          Regular         0.016687
# 34        17.50          Low Fat         0.097904

# %%
data.iloc[:,[1]].shape
# Out:
# (8523, 1)

# %%
data.iloc[[1],:].shape
# Out:
# (1, 12)

# %%
data.iloc[0,0]
# Out:
# 'FDA15'

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
data.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
data.tail(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8513           FDH31       12.000          Regular         0.020407
# 8514           FDA01       15.000          Regular         0.054489
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8513                Meat   99.9042            OUT035
# 8514              Canned   57.5904            OUT045
# 8515        Baking Goods  157.5288            OUT018
# ...

# %%
data[10:15]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 10           FDY07        11.80          Low Fat         0.000000
# 11           FDA03        18.50          Regular         0.045464
# 12           FDX32        15.10          Regular         0.100014
# 13           FDS46        17.60          Regular         0.047257
# 14           FDF32        16.35          Low Fat         0.068024
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 10  Fruits and Vegetables   45.5402            OUT049
# 11                  Dairy  144.1102            OUT046
# 12  Fruits and Vegetables  145.4786            OUT049
# 13            Snack Foods  119.6782            OUT046
# 14  Fruits and Vegetables  196.4426            OUT013
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 10                       1999      Medium               Tier 1
# 11                       1997       Small               Tier 1
# ...

# %%
data.iloc[10:15]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 10           FDY07        11.80          Low Fat         0.000000
# 11           FDA03        18.50          Regular         0.045464
# 12           FDX32        15.10          Regular         0.100014
# 13           FDS46        17.60          Regular         0.047257
# 14           FDF32        16.35          Low Fat         0.068024
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 10  Fruits and Vegetables   45.5402            OUT049
# 11                  Dairy  144.1102            OUT046
# 12  Fruits and Vegetables  145.4786            OUT049
# 13            Snack Foods  119.6782            OUT046
# 14  Fruits and Vegetables  196.4426            OUT013
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 10                       1999      Medium               Tier 1
# 11                       1997       Small               Tier 1
# ...

# %%
data.set_index('Item_Weight', inplace=True)

# %%
data.head(109)
# Out:
#             Item_Identifier Item_Fat_Content  Item_Visibility  \
# Item_Weight
# 9.300                 FDA15          Low Fat         0.016047
# 5.920                 DRC01          Regular         0.019278
# 17.500                FDN15          Low Fat         0.016760
# 19.200                FDX07          Regular         0.000000
# 8.930                 NCD19          Low Fat         0.000000
# ...                     ...              ...              ...
# 19.750                FDP09          Low Fat         0.034028
# 17.100                FDH14          Regular         0.046770
# 10.500                FDA47          Regular         0.116577
# 6.635                 FDG12          Regular         0.000000
# NaN                   DRE60          low fat         0.278974
#
#                          Item_Type  Item_MRP Outlet_Identifier  \
# Item_Weight
# 9.300                        Dairy  249.8092            OUT049
# 5.920                  Soft Drinks   48.2692            OUT018
# ...

# %%
data[10:15]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-b5ea8cfbf01f> in <module>
# ----> 1 data[10:15]
#
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2777
#    2778         # Do we have a slicer (on rows)?
# -> 2779         indexer = convert_to_index_sliceable(self, key)
#    2780         if indexer is not None:
#    2781             # either we have a slice or we have a string that can be converted
#
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\indexing.py in convert_to_index_sliceable(obj, key)
#    2264     idx = obj.index
#    2265     if isinstance(key, slice):
# -> 2266         return idx._convert_slice_indexer(key, kind="getitem")
#    2267
#    2268     elif isinstance(key, str):
#
# ...

# %%
data.iloc[10:15]
# Out:
#             Item_Identifier Item_Fat_Content  Item_Visibility  \
# Item_Weight
# 11.80                 FDY07          Low Fat         0.000000
# 18.50                 FDA03          Regular         0.045464
# 15.10                 FDX32          Regular         0.100014
# 17.60                 FDS46          Regular         0.047257
# 16.35                 FDF32          Low Fat         0.068024
#
#                          Item_Type  Item_MRP Outlet_Identifier  \
# Item_Weight
# 11.80        Fruits and Vegetables   45.5402            OUT049
# 18.50                        Dairy  144.1102            OUT046
# 15.10        Fruits and Vegetables  145.4786            OUT049
# 17.60                  Snack Foods  119.6782            OUT046
# 16.35        Fruits and Vegetables  196.4426            OUT013
#
#              Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Weight
# 11.80                             1999      Medium               Tier 1
# ...

# %%
data.reset_index()
# Out:
#       Item_Weight Item_Identifier Item_Fat_Content  Item_Visibility  \
# 0           9.300           FDA15          Low Fat         0.016047
# 1           5.920           DRC01          Regular         0.019278
# 2          17.500           FDN15          Low Fat         0.016760
# 3          19.200           FDX07          Regular         0.000000
# 4           8.930           NCD19          Low Fat         0.000000
# ...           ...             ...              ...              ...
# 8518        6.865           FDF22          Low Fat         0.056783
# 8519        8.380           FDS36          Regular         0.046982
# 8520       10.600           NCJ29          Low Fat         0.035186
# 8521        7.210           FDN46          Regular         0.145221
# 8522       14.800           DRG01          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.iloc[0:0]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
data.iloc[0:1]
# Out:
#             Item_Identifier Item_Fat_Content  Item_Visibility Item_Type  \
# Item_Weight
# 9.3                   FDA15          Low Fat         0.016047     Dairy
#
#              Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Weight
# 9.3          249.8092            OUT049                       1999
#
#             Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Item_Weight
# 9.3              Medium               Tier 1  Supermarket Type1
#
#              Item_Outlet_Sales
# Item_Weight
# 9.3                   3735.138

# %%
data.iloc[0:2]
# Out:
#             Item_Identifier Item_Fat_Content  Item_Visibility    Item_Type  \
# Item_Weight
# 9.30                  FDA15          Low Fat         0.016047        Dairy
# 5.92                  DRC01          Regular         0.019278  Soft Drinks
#
#              Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Weight
# 9.30         249.8092            OUT049                       1999
# 5.92          48.2692            OUT018                       2009
#
#             Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Item_Weight
# 9.30             Medium               Tier 1  Supermarket Type1
# 5.92             Medium               Tier 3  Supermarket Type2
#
#              Item_Outlet_Sales
# Item_Weight
# 9.30                 3735.1380
# 5.92                  443.4228

# %%
data.reset_index(inplace=True)

# %%
data.iloc[1:3]
# Out:
#    Item_Weight Item_Identifier Item_Fat_Content  Item_Visibility    Item_Type  \
# 1         5.92           DRC01          Regular         0.019278  Soft Drinks
# 2        17.50           FDN15          Low Fat         0.016760         Meat
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700

# %%
data.head()
# Out:
#    Item_Weight Item_Identifier Item_Fat_Content  Item_Visibility  \
# 0         9.30           FDA15          Low Fat         0.016047
# 1         5.92           DRC01          Regular         0.019278
# 2        17.50           FDN15          Low Fat         0.016760
# 3        19.20           FDX07          Regular         0.000000
# 4         8.93           NCD19          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.iloc[0:3]
# Out:
#    Item_Weight Item_Identifier Item_Fat_Content  Item_Visibility    Item_Type  \
# 0         9.30           FDA15          Low Fat         0.016047        Dairy
# 1         5.92           DRC01          Regular         0.019278  Soft Drinks
# 2        17.50           FDN15          Low Fat         0.016760         Meat
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700

# %%
data[2:4]
# Out:
#    Item_Weight Item_Identifier Item_Fat_Content  Item_Visibility  \
# 2         17.5           FDN15          Low Fat          0.01676
# 3         19.2           FDX07          Regular          0.00000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 2                   Meat   141.618            OUT049
# 3  Fruits and Vegetables   182.095            OUT010
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 2  Supermarket Type1            2097.27
# 3      Grocery Store             732.38

# %%
data.iloc[0,0]
# Out:
# 9.3

# %%
data.iloc[0,:]
# Out:
# Item_Weight                                9.3
# Item_Identifier                          FDA15
# Item_Fat_Content                       Low Fat
# Item_Visibility                      0.0160473
# Item_Type                                Dairy
# Item_MRP                               249.809
# Outlet_Identifier                       OUT049
# Outlet_Establishment_Year                 1999
# Outlet_Size                             Medium
# Outlet_Location_Type                    Tier 1
# Outlet_Type                  Supermarket Type1
# Item_Outlet_Sales                      3735.14
# Name: 0, dtype: object

# %%
data.iloc[:,:]
# Out:
#       Item_Weight Item_Identifier Item_Fat_Content  Item_Visibility  \
# 0           9.300           FDA15          Low Fat         0.016047
# 1           5.920           DRC01          Regular         0.019278
# 2          17.500           FDN15          Low Fat         0.016760
# 3          19.200           FDX07          Regular         0.000000
# 4           8.930           NCD19          Low Fat         0.000000
# ...           ...             ...              ...              ...
# 8518        6.865           FDF22          Low Fat         0.056783
# 8519        8.380           FDS36          Regular         0.046982
# 8520       10.600           NCJ29          Low Fat         0.035186
# 8521        7.210           FDN46          Regular         0.145221
# 8522       14.800           DRG01          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.iloc[[1],:].shape
# Out:
# (1, 12)

# %%
data.iloc[:,1].shape
# Out:
# (8523,)

# %%
data.iloc[[1,3,5,7,9]]
# Out:
#    Item_Weight Item_Identifier Item_Fat_Content  Item_Visibility  \
# 1        5.920           DRC01          Regular         0.019278
# 3       19.200           FDX07          Regular         0.000000
# 5       10.395           FDP36          Regular         0.000000
# 7          NaN           FDP10          Low Fat         0.127470
# 9       19.200           FDU28          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 1            Soft Drinks   48.2692            OUT018
# 3  Fruits and Vegetables  182.0950            OUT010
# 5           Baking Goods   51.4008            OUT018
# 7            Snack Foods  107.7622            OUT027
# 9           Frozen Foods  187.8214            OUT017
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1                       2009      Medium               Tier 3
# 3                       1998         NaN               Tier 3
# ...

# %%
data.iloc[[1,3,5,7,9],[2,4,6,8]]
# Out:
#   Item_Fat_Content              Item_Type Outlet_Identifier Outlet_Size
# 1          Regular            Soft Drinks            OUT018      Medium
# 3          Regular  Fruits and Vegetables            OUT010         NaN
# 5          Regular           Baking Goods            OUT018      Medium
# 7          Low Fat            Snack Foods            OUT027      Medium
# 9          Regular           Frozen Foods            OUT017         NaN
