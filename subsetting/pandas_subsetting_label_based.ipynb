# %%
import pandas as pd

# %%
data = pd.read_csv('../dataset/csv/big_mart_sales.csv')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.set_index('Item_Identifier', inplace=True, drop=True)

# %%
data.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...

# %%
data.loc['FDA15']
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# Item_Identifier
# FDA15                    9.3          Low Fat         0.016047     Dairy
# FDA15                    9.3          Low Fat         0.016055     Dairy
# FDA15                    9.3          Low Fat         0.016019     Dairy
# FDA15                    9.3          Low Fat         0.016088     Dairy
# FDA15                    9.3          Low Fat         0.026818     Dairy
# FDA15                    9.3          Low Fat         0.016009     Dairy
# FDA15                    NaN          Low Fat         0.015945     Dairy
# FDA15                    9.3               LF         0.016113     Dairy
#
#                  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Identifier
# FDA15            249.8092            OUT049                       1999
# FDA15            250.2092            OUT045                       2002
# ...

# %%
data.index
# Out:
# Index(['FDA15', 'DRC01', 'FDN15', 'FDX07', 'NCD19', 'FDP36', 'FDO10', 'FDP10',
#        'FDH17', 'FDU28',
#        ...
#        'FDH31', 'FDA01', 'FDH24', 'NCJ19', 'FDF53', 'FDF22', 'FDS36', 'NCJ29',
#        'FDN46', 'DRG01'],
#       dtype='object', name='Item_Identifier', length=8523)

# %%
data['FDA15':'DR01']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-b7588fad5b1e> in <module>
# ----> 1 data['FDA15':'DR01']
#
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2777
#    2778         # Do we have a slicer (on rows)?
# -> 2779         indexer = convert_to_index_sliceable(self, key)
#    2780         if indexer is not None:
#    2781             # either we have a slice or we have a string that can be converted
#
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\indexing.py in convert_to_index_sliceable(obj, key)
#    2264     idx = obj.index
#    2265     if isinstance(key, slice):
# -> 2266         return idx._convert_slice_indexer(key, kind="getitem")
#    2267
#    2268     elif isinstance(key, str):
#
# ...

# %%
data.loc[['FDA15', 'FDN15'], ['Item_Fat_Content', 'Item_Type']]
# Out:
#                 Item_Fat_Content Item_Type
# Item_Identifier
# FDA15                    Low Fat     Dairy
# FDA15                    Low Fat     Dairy
# FDA15                    Low Fat     Dairy
# FDA15                    Low Fat     Dairy
# FDA15                    Low Fat     Dairy
# FDA15                    Low Fat     Dairy
# FDA15                    Low Fat     Dairy
# FDA15                         LF     Dairy
# FDN15                    Low Fat      Meat
# FDN15                    Low Fat      Meat
# FDN15                    Low Fat      Meat
# FDN15                    Low Fat      Meat
# FDN15                    Low Fat      Meat
# FDN15                    Low Fat      Meat
# FDN15                    Low Fat      Meat

# %%
data.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...

# %%
data.set_index('Item_Weight', inplace=True)

# %%
data.head()
# Out:
#             Item_Fat_Content  Item_Visibility              Item_Type  \
# Item_Weight
# 9.30                 Low Fat         0.016047                  Dairy
# 5.92                 Regular         0.019278            Soft Drinks
# 17.50                Low Fat         0.016760                   Meat
# 19.20                Regular         0.000000  Fruits and Vegetables
# 8.93                 Low Fat         0.000000              Household
#
#              Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Weight
# 9.30         249.8092            OUT049                       1999
# 5.92          48.2692            OUT018                       2009
# 17.50        141.6180            OUT049                       1999
# 19.20        182.0950            OUT010                       1998
# 8.93          53.8614            OUT013                       1987
#
#             Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Item_Weight
# ...

# %%
data.loc[9.30:17.50]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-c862a76bd353> in <module>
# ----> 1 data.loc[9.30:17.50]
#
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1909         if isinstance(key, slice):
#    1910             self._validate_key(key, axis)
# -> 1911             return self._get_slice_axis(key, axis=axis)
#    1912         elif com.is_bool_indexer(key):
#    1913             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
data.iloc[0:13]
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                  9.300          Low Fat         0.016047
# DRC01                  5.920          Regular         0.019278
# FDN15                 17.500          Low Fat         0.016760
# FDX07                 19.200          Regular         0.000000
# NCD19                  8.930          Low Fat         0.000000
# FDP36                 10.395          Regular         0.000000
# FDO10                 13.650          Regular         0.012741
# FDP10                    NaN          Low Fat         0.127470
# FDH17                 16.200          Regular         0.016687
# FDU28                 19.200          Regular         0.094450
# FDY07                 11.800          Low Fat         0.000000
# FDA03                 18.500          Regular         0.045464
# FDX32                 15.100          Regular         0.100014
#
# ...

# %%
data.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...

# %%
sample_df = pd.DataFrame({
    'gender': ['M','F','M','M','F'],
    'grade' : ['A','A','B','B','A'],
    'marks' : [22, 21, 12, 14, 20],
    'id' : ['A101', 'A102', 'A103', 'A104', 'A105']
})

# %%
sample_df.head()
# Out:
#   gender grade  marks    id
# 0      M     A     22  A101
# 1      F     A     21  A102
# 2      M     B     12  A103
# 3      M     B     14  A104
# 4      F     A     20  A105

# %%
sample_df.loc[2:4]
# Out:
#   gender grade  marks    id
# 2      M     B     12  A103
# 3      M     B     14  A104
# 4      F     A     20  A105

# %%
sample_df.iloc[2:4]
# Out:
#   gender grade  marks    id
# 2      M     B     12  A103
# 3      M     B     14  A104

# %%
sample_df = sample_df.sort_values(by=['marks'])

# %%
sample_df.head()
# Out:
#   gender grade  marks    id
# 2      M     B     12  A103
# 3      M     B     14  A104
# 4      F     A     20  A105
# 1      F     A     21  A102
# 0      M     A     22  A101

# %%
sample_df.loc[2:4]
# Out:
#   gender grade  marks    id
# 2      M     B     12  A103
# 3      M     B     14  A104
# 4      F     A     20  A105

# %%
sample_df.iloc[2:4]
# Out:
#   gender grade  marks    id
# 4      F     A     20  A105
# 1      F     A     21  A102

# %%
sample_df.reset_index(inplace=True)
sample_df.set_index('id', inplace=True, drop=True)

# %%
sample_df.head()
# Out:
#      gender grade  marks
# id
# A103      M     B     12
# A104      M     B     14
# A105      F     A     20
# A102      F     A     21
# A101      M     A     22

# %%
#sample_df['Gender']=='Male'

# %%
sample_df.iloc[2:4]
# Out:
#      gender grade  marks
# id
# A105      F     A     20
# A102      F     A     21

# %%
sample_df.iloc['A103':'A101']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-6d729bbfd315> in <module>
# ----> 1 sample_df.iloc['A103':'A101']
#
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2115     def _getitem_axis(self, key, axis: int):
#    2116         if isinstance(key, slice):
# -> 2117             return self._get_slice_axis(key, axis=axis)
#    2118
#    2119         if isinstance(key, list):
#
# ...

# %%
sample_df.loc[2:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-a0b024ef820d> in <module>
# ----> 1 sample_df.loc[2:4]
#
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1909         if isinstance(key, slice):
#    1910             self._validate_key(key, axis)
# -> 1911             return self._get_slice_axis(key, axis=axis)
#    1912         elif com.is_bool_indexer(key):
#    1913             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
data.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...

# %%
data['FDA15']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Sandeep\Installations\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FDA15'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-e7bc133016b5> in <module>
# ----> 1 data['FDA15']
#
# ...

# %%
data.loc['FDA15']
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# Item_Identifier
# FDA15                    9.3          Low Fat         0.016047     Dairy
# FDA15                    9.3          Low Fat         0.016055     Dairy
# FDA15                    9.3          Low Fat         0.016019     Dairy
# FDA15                    9.3          Low Fat         0.016088     Dairy
# FDA15                    9.3          Low Fat         0.026818     Dairy
# FDA15                    9.3          Low Fat         0.016009     Dairy
# FDA15                    NaN          Low Fat         0.015945     Dairy
# FDA15                    9.3               LF         0.016113     Dairy
#
#                  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Identifier
# FDA15            249.8092            OUT049                       1999
# FDA15            250.2092            OUT045                       2002
# ...

# %%
data.loc[['FDA15','FDN16']]
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility     Item_Type  \
# Item_Identifier
# FDA15                    9.3          Low Fat         0.016047         Dairy
# FDA15                    9.3          Low Fat         0.016055         Dairy
# FDA15                    9.3          Low Fat         0.016019         Dairy
# FDA15                    9.3          Low Fat         0.016088         Dairy
# FDA15                    9.3          Low Fat         0.026818         Dairy
# FDA15                    9.3          Low Fat         0.016009         Dairy
# FDA15                    NaN          Low Fat         0.015945         Dairy
# FDA15                    9.3               LF         0.016113         Dairy
# FDN16                   12.6          Regular         0.062648  Frozen Foods
# FDN16                   12.6          Regular         0.062700  Frozen Foods
# FDN16                   12.6          Regular         0.063055  Frozen Foods
# ...
