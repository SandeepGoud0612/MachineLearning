# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import warnings
warnings.filterwarnings(action='ignore')
sns.set()

# %%
df = pd.read_csv('nyc_taxi_trip_duration.csv')

# %%
df.shape
# Out:
# (729322, 11)

# %%
df.columns
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'dropoff_datetime',
#        'passenger_count', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'store_and_fwd_flag',
#        'trip_duration'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 729322 entries, 0 to 729321
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  729322 non-null  object
#  1   vendor_id           729322 non-null  int64
#  2   pickup_datetime     729322 non-null  object
#  3   dropoff_datetime    729322 non-null  object
#  4   passenger_count     729322 non-null  int64
#  5   pickup_longitude    729322 non-null  float64
#  6   pickup_latitude     729322 non-null  float64
#  7   dropoff_longitude   729322 non-null  float64
#  8   dropoff_latitude    729322 non-null  float64
#  9   store_and_fwd_flag  729322 non-null  object
#  10  trip_duration       729322 non-null  int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 61.2+ MB

# %%
df.dtypes
# Out:
# id                     object
# vendor_id               int64
# pickup_datetime        object
# dropoff_datetime       object
# passenger_count         int64
# pickup_longitude      float64
# pickup_latitude       float64
# dropoff_longitude     float64
# dropoff_latitude      float64
# store_and_fwd_flag     object
# trip_duration           int64
# dtype: object

# %%
df.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id1080784          2  2016-02-29 16:40:21  2016-02-29 16:47:01
# 1  id0889885          1  2016-03-11 23:35:37  2016-03-11 23:53:57
# 2  id0857912          2  2016-02-21 17:59:33  2016-02-21 18:26:48
# 3  id3744273          2  2016-01-05 09:44:31  2016-01-05 10:03:32
# 4  id0232939          1  2016-02-17 06:42:23  2016-02-17 06:56:31
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.953918        40.778873         -73.963875
# 1                2        -73.988312        40.731743         -73.994751
# 2                2        -73.997314        40.721458         -73.948029
# 3                6        -73.961670        40.759720         -73.956779
# 4                1        -74.017120        40.708469         -73.988182
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.771164                  N            400
# 1         40.694931                  N           1100
# 2         40.774918                  N           1635
# 3         40.780628                  N           1141
# 4         40.740631                  N            848

# %%
df.describe()
# Out:
#            vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  729322.000000    729322.000000     729322.000000    729322.000000
# mean        1.535403         1.662055        -73.973513        40.750919
# std         0.498745         1.312446          0.069754         0.033594
# min         1.000000         0.000000       -121.933342        34.712234
# 25%         1.000000         1.000000        -73.991859        40.737335
# 50%         2.000000         1.000000        -73.981758        40.754070
# 75%         2.000000         2.000000        -73.967361        40.768314
# max         2.000000         9.000000        -65.897385        51.881084
#
#        dropoff_longitude  dropoff_latitude  trip_duration
# count      729322.000000     729322.000000   7.293220e+05
# mean          -73.973422         40.751775   9.522291e+02
# std             0.069588          0.036037   3.864626e+03
# min          -121.933304         32.181141   1.000000e+00
# 25%           -73.991318         40.735931   3.970000e+02
# 50%           -73.979759         40.754509   6.630000e+02
# 75%           -73.963036         40.769741   1.075000e+03
# max           -65.897385         43.921028   1.939736e+06

# %%
df.isnull().sum()
# Out:
# id                    0
# vendor_id             0
# pickup_datetime       0
# dropoff_datetime      0
# passenger_count       0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude     0
# dropoff_latitude      0
# store_and_fwd_flag    0
# trip_duration         0
# dtype: int64

# %%
non_num_cols=['id','pickup_datetime','dropoff_datetime','store_and_fwd_flag']
print(df[non_num_cols].count())
# Out:
# id                    729322
# pickup_datetime       729322
# dropoff_datetime      729322
# store_and_fwd_flag    729322
# dtype: int64

# %%
df['pickup_datetime']=pd.to_datetime(df['pickup_datetime'])
df['dropoff_datetime']=pd.to_datetime(df['dropoff_datetime'])

# %%
df['pickup_day']=df['pickup_datetime'].dt.day_name()
df['dropoff_day']=df['dropoff_datetime'].dt.day_name()

# %%
df['pickup_day'].value_counts()
# Out:
# Friday       111744
# Saturday     110252
# Thursday     109344
# Wednesday    105074
# Tuesday      101254
# Sunday        97682
# Monday        93972
# Name: pickup_day, dtype: int64

# %%
df['dropoff_day'].value_counts()
# Out:
# Friday       111509
# Saturday     110289
# Thursday     108918
# Wednesday    104944
# Tuesday      101142
# Sunday        98561
# Monday        93959
# Name: dropoff_day, dtype: int64

# %%
def timezone(x):
    if x>=datetime.time(4, 0, 1) and x <=datetime.time(10, 0, 0):
        return 'morning'
    elif x>=datetime.time(10, 0, 1) and x <=datetime.time(16, 0, 0):
        return 'midday'
    elif x>=datetime.time(16, 0, 1) and x <=datetime.time(22, 0, 0):
        return 'evening'
    elif x>=datetime.time(22, 0, 1) or x <=datetime.time(4, 0, 0):
        return 'late night'
    
df['pickup_timezone']=df['pickup_datetime'].apply(lambda x :timezone(datetime.datetime.strptime(str(x), "%Y-%m-%d %H:%M:%S").time()) )
df['dropoff_timezone']=df['dropoff_datetime'].apply(lambda x :timezone(datetime.datetime.strptime(str(x), "%Y-%m-%d %H:%M:%S").time()) )

# %%
print( df['trip_duration'].nlargest(10))
# Out:
# 21813     1939736
# 259437      86391
# 119185      86387
# 177225      86378
# 496391      86377
# 90557       86369
# 673847      86369
# 163178      86367
# 179065      86365
# 248675      86364
# Name: trip_duration, dtype: int64

# %%
df=df[df.trip_duration!=df.trip_duration.max()]

# %%
print( df['trip_duration'].nlargest(10))
# Out:
# 259437    86391
# 119185    86387
# 177225    86378
# 496391    86377
# 90557     86369
# 673847    86369
# 163178    86367
# 179065    86365
# 248675    86364
# 680575    86363
# Name: trip_duration, dtype: int64

# %%
bins=np.array([0,1800,3600,5400,7200,90000])
df['duration_time']=pd.cut(df.trip_duration,bins,labels=["< 5", "5-10", "10-15","15-20",">20"])

# %%
df.head()
# Out:
#           id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0  id1080784          2 2016-02-29 16:40:21 2016-02-29 16:47:01
# 1  id0889885          1 2016-03-11 23:35:37 2016-03-11 23:53:57
# 2  id0857912          2 2016-02-21 17:59:33 2016-02-21 18:26:48
# 3  id3744273          2 2016-01-05 09:44:31 2016-01-05 10:03:32
# 4  id0232939          1 2016-02-17 06:42:23 2016-02-17 06:56:31
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.953918        40.778873         -73.963875
# 1                2        -73.988312        40.731743         -73.994751
# 2                2        -73.997314        40.721458         -73.948029
# 3                6        -73.961670        40.759720         -73.956779
# 4                1        -74.017120        40.708469         -73.988182
#
#    dropoff_latitude store_and_fwd_flag  trip_duration pickup_day dropoff_day  \
# 0         40.771164                  N            400     Monday      Monday
# 1         40.694931                  N           1100     Friday      Friday
# 2         40.774918                  N           1635     Sunday      Sunday
# 3         40.780628                  N           1141    Tuesday     Tuesday
# 4         40.740631                  N            848  Wednesday   Wednesday
#
#   pickup_timezone dropoff_timezone duration_time
# 0         evening          evening           < 5
# 1      late night       late night           < 5
# 2         evening          evening           < 5
# 3         morning           midday           < 5
# 4         morning          morning           < 5

# %%
df['trip_duration'].nlargest(5)
# Out:
# 259437    86391
# 119185    86387
# 177225    86378
# 496391    86377
# 90557     86369
# Name: trip_duration, dtype: int64

# %%
len(df[df['trip_duration']==1])
# Out:
# 13

# %%
df=df[df['trip_duration']!=df['trip_duration'].min()]

# %%
len(df[df['trip_duration']==1])
# Out:
# 0

# %%
df['trip_duration'].nsmallest(10)
# Out:
# 3169     2
# 20225    2
# 43683    2
# 47266    2
# 52233    2
# 62589    2
# 69490    2
# 79486    2
# 81585    2
# 83915    2
# Name: trip_duration, dtype: int64

# %%
sns.distplot(df['trip_duration'])

# %%
df['trip_duration_hour']=df['trip_duration']/3600

# %%
df['trip_duration_hour'].describe()
# Out:
# count    729308.000000
# mean          0.263774
# std           0.868763
# min           0.000556
# 25%           0.110278
# 50%           0.184167
# 75%           0.298611
# max          23.997500
# Name: trip_duration_hour, dtype: float64

# %%
sns.distplot(df['trip_duration_hour'])

# %%
df=df[df['passenger_count']<=6]
df=df[df['passenger_count']!=0]

# %%
df['passenger_count'].value_counts()
# Out:
# 1    517403
# 2    105096
# 5     38926
# 3     29692
# 6     24107
# 4     14050
# Name: passenger_count, dtype: int64

# %%
df.dtypes
# Out:
# id                            object
# vendor_id                      int64
# pickup_datetime       datetime64[ns]
# dropoff_datetime      datetime64[ns]
# passenger_count                int64
# pickup_longitude             float64
# pickup_latitude              float64
# dropoff_longitude            float64
# dropoff_latitude             float64
# store_and_fwd_flag            object
# trip_duration                  int64
# pickup_day                    object
# dropoff_day                   object
# pickup_timezone               object
# dropoff_timezone              object
# duration_time               category
# trip_duration_hour           float64
# dtype: object

# %%
df['pickup_day']=df['pickup_datetime'].dt.day_name()
df['dropoff_day']=df['dropoff_datetime'].dt.day_name()
df['pickup_month']=df['pickup_datetime'].dt.month
df['dropoff_month']=df['dropoff_datetime'].dt.month

# %%
df['pickup_month'].value_counts()
# Out:
# 3    128307
# 4    125627
# 5    124194
# 2    119354
# 6    117404
# 1    114388
# Name: pickup_month, dtype: int64

# %%
df['dropoff_month'].value_counts()
# Out:
# 3    128275
# 4    125626
# 5    124229
# 2    119351
# 6    117378
# 1    114362
# 7        53
# Name: dropoff_month, dtype: int64

# %%
print(df[df['dropoff_month']==7]['pickup_datetime'].dt.month.value_counts())
print(df[df.dropoff_month==7].pickup_datetime.dt.day.value_counts())
# Out:
# 6    53
# Name: pickup_datetime, dtype: int64
# 30    53
# Name: pickup_datetime, dtype: int64

# %%
#a function is created to calculate the distance from latitudes and longitudes
from math import radians, cos, sin, asin, sqrt
def haversine(df):
    lat1, lon1, lat2, lon2 = df.pickup_latitude,df.pickup_longitude,df.dropoff_latitude,df.dropoff_longitude 
    R = 3959.87433 # this is in miles.  For Earth radius in kilometers use 6372.8 km
    dLat = radians(lat2 - lat1)
    dLon = radians(lon2 - lon1)
    lat1 = radians(lat1)
    lat2 = radians(lat2)
    a = sin(dLat/2)**2 + cos(lat1)*cos(lat2)*sin(dLon/2)**2
    c = 2*asin(sqrt(a))
    return R * c

# %%
df['distance'] = df.apply(lambda x: haversine(x), axis=1)

# %%
sns.scatterplot(x='distance',y='trip_duration',data=df)

# %%
len(df[df['distance']==0])
# Out:
# 2889

# %%
mean_dist = df['distance'].mean()
mean_dist
# Out:
# 2.138898403752463

# %%
df.loc[df['distance']==0,'distance']=mean_dist

# %%
df['speed']=df['distance']/df['trip_duration_hour']
sns.boxplot(df['speed'])

# %%
sns.scatterplot(x='distance',y='trip_duration_hour',data=df)

# %%
df['log_distance']=np.log(df['distance'])
df['log_trip_duration']=np.log(df['trip_duration_hour'])
sns.scatterplot(x='log_distance',y='log_trip_duration',data=df)

# %%
df=df[df.log_trip_duration<2]

# %%
df.columns
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'dropoff_datetime',
#        'passenger_count', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'store_and_fwd_flag',
#        'trip_duration', 'pickup_day', 'dropoff_day', 'pickup_timezone',
#        'dropoff_timezone', 'duration_time', 'trip_duration_hour',
#        'pickup_month', 'dropoff_month', 'distance', 'speed', 'log_distance',
#        'log_trip_duration'],
#       dtype='object')

# %%
data2=df.loc[:,['passenger_count','store_and_fwd_flag','trip_duration', 'pickup_day', 'dropoff_day', 'pickup_month',
   'dropoff_month','pickup_timezone','dropoff_timezone','speed','log_distance','distance']]

# %%
data2.dtypes
# Out:
# passenger_count         int64
# store_and_fwd_flag     object
# trip_duration           int64
# pickup_day             object
# dropoff_day            object
# pickup_month            int64
# dropoff_month           int64
# pickup_timezone        object
# dropoff_timezone       object
# speed                 float64
# log_distance          float64
# distance              float64
# dtype: object

# %%
data2.head()
# Out:
#    passenger_count store_and_fwd_flag  trip_duration pickup_day dropoff_day  \
# 0                1                  N            400     Monday      Monday
# 1                2                  N           1100     Friday      Friday
# 2                2                  N           1635     Sunday      Sunday
# 3                6                  N           1141    Tuesday     Tuesday
# 4                1                  N            848  Wednesday   Wednesday
#
#    pickup_month  dropoff_month pickup_timezone dropoff_timezone      speed  \
# 0             2              2         evening          evening   6.707517
# 1             3              3      late night       late night   8.399243
# 2             2              2         evening          evening   9.922969
# 3             1              1         morning           midday   4.630251
# 4             2              2         morning          morning  11.421451
#
#    log_distance  distance
# 0     -0.293996  0.745280
# 1      0.942518  2.566436
# 2      1.505561  4.506682
# 3      0.383582  1.467532
# 4      0.989685  2.690386

# %%
data2=pd.get_dummies(data2,columns=['store_and_fwd_flag','pickup_day','dropoff_day','pickup_month','dropoff_month','pickup_timezone', 'dropoff_timezone'])

# %%
data2.dtypes
# Out:
# passenger_count                  int64
# trip_duration                    int64
# speed                          float64
# log_distance                   float64
# distance                       float64
# store_and_fwd_flag_N             uint8
# store_and_fwd_flag_Y             uint8
# pickup_day_Friday                uint8
# pickup_day_Monday                uint8
# pickup_day_Saturday              uint8
# pickup_day_Sunday                uint8
# pickup_day_Thursday              uint8
# pickup_day_Tuesday               uint8
# pickup_day_Wednesday             uint8
# dropoff_day_Friday               uint8
# dropoff_day_Monday               uint8
# dropoff_day_Saturday             uint8
# dropoff_day_Sunday               uint8
# dropoff_day_Thursday             uint8
# dropoff_day_Tuesday              uint8
# dropoff_day_Wednesday            uint8
# pickup_month_1                   uint8
# pickup_month_2                   uint8
# pickup_month_3                   uint8
# pickup_month_4                   uint8
# pickup_month_5                   uint8
# pickup_month_6                   uint8
# dropoff_month_1                  uint8
# dropoff_month_2                  uint8
# dropoff_month_3                  uint8
# dropoff_month_4                  uint8
# dropoff_month_5                  uint8
# dropoff_month_6                  uint8
# dropoff_month_7                  uint8
# pickup_timezone_evening          uint8
# pickup_timezone_late night       uint8
# pickup_timezone_midday           uint8
# pickup_timezone_morning          uint8
# dropoff_timezone_evening         uint8
# dropoff_timezone_late night      uint8
# dropoff_timezone_midday          uint8
# dropoff_timezone_morning         uint8
# dtype: object

# %%
data2.corr()
# Out:
#                              passenger_count  trip_duration     speed  \
# passenger_count                     1.000000       0.014740 -0.008751
# trip_duration                       0.014740       1.000000 -0.023743
# speed                              -0.008751      -0.023743  1.000000
# log_distance                        0.012491       0.694821  0.068430
# distance                            0.009251       0.686604  0.098527
# store_and_fwd_flag_N                0.020851      -0.028826 -0.005297
# store_and_fwd_flag_Y               -0.020851       0.028826  0.005297
# pickup_day_Friday                  -0.001782       0.020540 -0.003565
# pickup_day_Monday                  -0.008850      -0.015985  0.004753
# pickup_day_Saturday                 0.022535      -0.037556  0.002098
# pickup_day_Sunday                   0.016282      -0.044531  0.014121
# pickup_day_Thursday                -0.009569       0.037427 -0.006137
# pickup_day_Tuesday                 -0.007998       0.010539 -0.004954
# pickup_day_Wednesday               -0.010897       0.027244 -0.005595
# dropoff_day_Friday                 -0.001935       0.019901 -0.003427
# dropoff_day_Monday                 -0.008698      -0.016442  0.004801
# dropoff_day_Saturday                0.022380      -0.036533  0.002141
# dropoff_day_Sunday                  0.016690      -0.042365  0.013714
# dropoff_day_Thursday               -0.009521       0.035528 -0.006095
# dropoff_day_Tuesday                -0.008375       0.010234 -0.004931
# dropoff_day_Wednesday              -0.010892       0.027669 -0.005562
# pickup_month_1                      0.002576      -0.030610  0.000955
# pickup_month_2                     -0.001707      -0.031335 -0.000946
# pickup_month_3                     -0.001196      -0.013076  0.000789
# pickup_month_4                      0.001951       0.006213  0.000240
# pickup_month_5                      0.000964       0.031500 -0.000593
# pickup_month_6                     -0.002581       0.036780 -0.000449
# dropoff_month_1                     0.002606      -0.030696  0.000944
# dropoff_month_2                    -0.001707      -0.031386 -0.000941
# dropoff_month_3                    -0.001208      -0.013174  0.000787
# dropoff_month_4                     0.001934       0.006344  0.000250
# dropoff_month_5                     0.000977       0.031523 -0.000605
# dropoff_month_6                    -0.002544       0.036654 -0.000439
# dropoff_month_7                    -0.002357       0.009244 -0.000043
# pickup_timezone_evening             0.005493       0.006519 -0.007326
# pickup_timezone_late night          0.013977      -0.045566  0.018189
# pickup_timezone_midday              0.001713       0.063581 -0.017177
# pickup_timezone_morning            -0.023606      -0.036084  0.010484
# dropoff_timezone_evening            0.005482       0.026822 -0.008721
# dropoff_timezone_late night         0.013958      -0.030186  0.017601
# dropoff_timezone_midday             0.001237       0.044705 -0.017194
# dropoff_timezone_morning           -0.023739      -0.055442  0.012743
#
#                              log_distance  distance  store_and_fwd_flag_N  \
# passenger_count                  0.012491  0.009251              0.020851
# trip_duration                    0.694821  0.686604             -0.028826
# speed                            0.068430  0.098527             -0.005297
# log_distance                     1.000000  0.733820             -0.019235
# distance                         0.733820  1.000000             -0.028315
# store_and_fwd_flag_N            -0.019235 -0.028315              1.000000
# store_and_fwd_flag_Y             0.019235  0.028315             -1.000000
# pickup_day_Friday               -0.004225 -0.003537             -0.002791
# pickup_day_Monday                0.003985  0.010763             -0.000582
# pickup_day_Saturday             -0.001203 -0.010145              0.002956
# pickup_day_Sunday                0.028371  0.024437              0.002697
# pickup_day_Thursday             -0.003998 -0.001744             -0.002877
# pickup_day_Tuesday              -0.012430 -0.009410              0.001051
# pickup_day_Wednesday            -0.009450 -0.008952             -0.000322
# dropoff_day_Friday              -0.004163 -0.003453             -0.002548
# dropoff_day_Monday               0.003752  0.010332             -0.000438
# dropoff_day_Saturday            -0.000592 -0.009168              0.002661
# dropoff_day_Sunday               0.029218  0.024291              0.002673
# dropoff_day_Thursday            -0.005082 -0.002667             -0.003050
# dropoff_day_Tuesday             -0.012502 -0.009203              0.001189
# dropoff_day_Wednesday           -0.009687 -0.008844             -0.000363
# pickup_month_1                  -0.008948 -0.006542             -0.001052
# pickup_month_2                  -0.013788 -0.012417              0.000899
# pickup_month_3                   0.000788 -0.000504              0.001574
# pickup_month_4                   0.000176 -0.001735             -0.002325
# pickup_month_5                   0.009941  0.011185              0.002444
# pickup_month_6                   0.011570  0.009840             -0.001605
# dropoff_month_1                 -0.009031 -0.006640             -0.001058
# dropoff_month_2                 -0.013776 -0.012384              0.000949
# dropoff_month_3                  0.000673 -0.000669              0.001517
# dropoff_month_4                  0.000259 -0.001598             -0.002325
# dropoff_month_5                  0.009933  0.011148              0.002500
# dropoff_month_6                  0.011516  0.009831             -0.001662
# dropoff_month_7                  0.007566  0.006322              0.000600
# pickup_timezone_evening         -0.013502 -0.015959             -0.000803
# pickup_timezone_late night       0.083495  0.054260              0.003119
# pickup_timezone_midday          -0.056467 -0.033905             -0.004264
# pickup_timezone_morning         -0.003673  0.003221              0.002810
# dropoff_timezone_evening        -0.012942 -0.010799             -0.002380
# dropoff_timezone_late night      0.095499  0.065187              0.002758
# dropoff_timezone_midday         -0.065377 -0.047066             -0.002822
# dropoff_timezone_morning        -0.008485 -0.000327              0.003439
#
#                              store_and_fwd_flag_Y  pickup_day_Friday  \
# passenger_count                         -0.020851          -0.001782
# trip_duration                            0.028826           0.020540
# speed                                    0.005297          -0.003565
# log_distance                             0.019235          -0.004225
# distance                                 0.028315          -0.003537
# store_and_fwd_flag_N                    -1.000000          -0.002791
# store_and_fwd_flag_Y                     1.000000           0.002791
# pickup_day_Friday                        0.002791           1.000000
# pickup_day_Monday                        0.000582          -0.163612
# pickup_day_Saturday                     -0.002956          -0.179471
# pickup_day_Sunday                       -0.002697          -0.167240
# pickup_day_Thursday                      0.002877          -0.178637
# pickup_day_Tuesday                      -0.001051          -0.170792
# pickup_day_Wednesday                     0.000322          -0.174529
# dropoff_day_Friday                       0.002548           0.985134
# dropoff_day_Monday                       0.000438          -0.163542
# dropoff_day_Saturday                    -0.002661          -0.163423
# dropoff_day_Sunday                      -0.002673          -0.168087
# dropoff_day_Thursday                     0.003050          -0.178248
# dropoff_day_Tuesday                     -0.001189          -0.170716
# dropoff_day_Wednesday                    0.000363          -0.174393
# pickup_month_1                           0.001052           0.032551
# pickup_month_2                          -0.000899          -0.006193
# pickup_month_3                          -0.001574          -0.018013
# pickup_month_4                           0.002325           0.026977
# pickup_month_5                          -0.002444          -0.019757
# pickup_month_6                           0.001605          -0.014821
# dropoff_month_1                          0.001058           0.032586
# dropoff_month_2                         -0.000949          -0.006190
# dropoff_month_3                         -0.001517          -0.017968
# dropoff_month_4                          0.002325           0.026977
# dropoff_month_5                         -0.002500          -0.019800
# dropoff_month_6                          0.001662          -0.014784
# dropoff_month_7                         -0.000600          -0.003417
# pickup_timezone_evening                  0.000803          -0.008407
# pickup_timezone_late night              -0.003119           0.015827
# pickup_timezone_midday                   0.004264          -0.017049
# pickup_timezone_morning                 -0.002810           0.014164
# dropoff_timezone_evening                 0.002380          -0.007886
# dropoff_timezone_late night             -0.002758           0.015578
# dropoff_timezone_midday                  0.002822          -0.017032
# dropoff_timezone_morning                -0.003439           0.013699
#
#                              pickup_day_Monday  pickup_day_Saturday  ...  \
# passenger_count                      -0.008850             0.022535  ...
# trip_duration                        -0.015985            -0.037556  ...
# speed                                 0.004753             0.002098  ...
# log_distance                          0.003985            -0.001203  ...
# distance                              0.010763            -0.010145  ...
# store_and_fwd_flag_N                 -0.000582             0.002956  ...
# store_and_fwd_flag_Y                  0.000582            -0.002956  ...
# pickup_day_Friday                    -0.163612            -0.179471  ...
# pickup_day_Monday                     1.000000            -0.162301  ...
# pickup_day_Saturday                  -0.162301             1.000000  ...
# pickup_day_Sunday                    -0.151241            -0.165901  ...
# pickup_day_Thursday                  -0.161548            -0.177207  ...
# pickup_day_Tuesday                   -0.154453            -0.169424  ...
# pickup_day_Wednesday                 -0.157833            -0.173132  ...
# dropoff_day_Friday                   -0.163422            -0.179263  ...
# dropoff_day_Monday                    0.992207            -0.162232  ...
# dropoff_day_Saturday                 -0.162349             0.984104  ...
# dropoff_day_Sunday                   -0.152006            -0.150388  ...
# dropoff_day_Thursday                 -0.161196            -0.176821  ...
# dropoff_day_Tuesday                  -0.146417            -0.169349  ...
# dropoff_day_Wednesday                -0.157710            -0.172997  ...
# pickup_month_1                       -0.011977            -0.000316  ...
# pickup_month_2                        0.030662             0.001112  ...
# pickup_month_3                       -0.015378            -0.011027  ...
# pickup_month_4                       -0.012937             0.040136  ...
# pickup_month_5                        0.018614            -0.015561  ...
# pickup_month_6                       -0.008832            -0.014703  ...
# dropoff_month_1                      -0.011949            -0.000284  ...
# dropoff_month_2                       0.030422             0.001115  ...
# dropoff_month_3                      -0.015101            -0.010983  ...
# dropoff_month_4                      -0.012937             0.039608  ...
# dropoff_month_5                       0.018571            -0.015074  ...
# dropoff_month_6                      -0.008798            -0.014666  ...
# dropoff_month_7                      -0.003090            -0.003390  ...
# pickup_timezone_evening               0.020313            -0.017361  ...
# pickup_timezone_late night           -0.055803             0.085197  ...
# pickup_timezone_midday                0.004904            -0.001993  ...
# pickup_timezone_morning               0.027631            -0.065745  ...
# dropoff_timezone_evening              0.020673            -0.017917  ...
# dropoff_timezone_late night          -0.053801             0.080426  ...
# dropoff_timezone_midday               0.006374            -0.004232  ...
# dropoff_timezone_morning              0.024857            -0.060095  ...
#
#                              dropoff_month_6  dropoff_month_7  \
# passenger_count                    -0.002544        -0.002357
# trip_duration                       0.036654         0.009244
# speed                              -0.000439        -0.000043
# log_distance                        0.011516         0.007566
# distance                            0.009831         0.006322
# store_and_fwd_flag_N               -0.001662         0.000600
# store_and_fwd_flag_Y                0.001662        -0.000600
# pickup_day_Friday                  -0.014784        -0.003417
# pickup_day_Monday                  -0.008798        -0.003090
# pickup_day_Saturday                -0.014666        -0.003390
# pickup_day_Sunday                  -0.013571        -0.003159
# pickup_day_Thursday                 0.030849         0.019129
# pickup_day_Tuesday                 -0.011207        -0.003226
# pickup_day_Wednesday                0.031348        -0.003296
# dropoff_day_Friday                 -0.014544         0.018909
# dropoff_day_Monday                 -0.008787        -0.003089
# dropoff_day_Saturday               -0.015058        -0.003391
# dropoff_day_Sunday                 -0.013365        -0.003175
# dropoff_day_Thursday                0.031326        -0.003367
# dropoff_day_Tuesday                -0.011658        -0.003224
# dropoff_day_Wednesday               0.031350        -0.003294
# pickup_month_1                     -0.188903        -0.003465
# pickup_month_2                     -0.193778        -0.003554
# pickup_month_3                     -0.202375        -0.003712
# pickup_month_4                     -0.199799        -0.003665
# pickup_month_5                     -0.198206        -0.003640
# pickup_month_6                      0.999644         0.018340
# dropoff_month_1                    -0.188884        -0.003464
# dropoff_month_2                    -0.193776        -0.003554
# dropoff_month_3                    -0.202346        -0.003711
# dropoff_month_4                    -0.199799        -0.003665
# dropoff_month_5                    -0.198463        -0.003640
# dropoff_month_6                     1.000000        -0.003519
# dropoff_month_7                    -0.003519         1.000000
# pickup_timezone_evening            -0.009277        -0.005720
# pickup_timezone_late night          0.010002         0.016082
# pickup_timezone_midday             -0.003487        -0.005126
# pickup_timezone_morning             0.005178        -0.003694
# dropoff_timezone_evening           -0.009483        -0.005719
# dropoff_timezone_late night         0.010753         0.015597
# dropoff_timezone_midday            -0.003107        -0.005109
# dropoff_timezone_morning            0.004058        -0.003584
#
#                              pickup_timezone_evening  \
# passenger_count                             0.005493
# trip_duration                               0.006519
# speed                                      -0.007326
# log_distance                               -0.013502
# distance                                   -0.015959
# store_and_fwd_flag_N                       -0.000803
# store_and_fwd_flag_Y                        0.000803
# pickup_day_Friday                          -0.008407
# pickup_day_Monday                           0.020313
# pickup_day_Saturday                        -0.017361
# pickup_day_Sunday                          -0.023814
# pickup_day_Thursday                         0.005609
# pickup_day_Tuesday                          0.015049
# pickup_day_Wednesday                        0.009520
# dropoff_day_Friday                         -0.007811
# dropoff_day_Monday                          0.020506
# dropoff_day_Saturday                       -0.017499
# dropoff_day_Sunday                         -0.026175
# dropoff_day_Thursday                        0.006701
# dropoff_day_Tuesday                         0.015258
# dropoff_day_Wednesday                       0.009957
# pickup_month_1                              0.002034
# pickup_month_2                              0.004975
# pickup_month_3                              0.004892
# pickup_month_4                              0.001120
# pickup_month_5                             -0.003812
# pickup_month_6                             -0.009340
# dropoff_month_1                             0.002088
# dropoff_month_2                             0.004973
# dropoff_month_3                             0.004969
# dropoff_month_4                             0.001128
# dropoff_month_5                            -0.003887
# dropoff_month_6                            -0.009277
# dropoff_month_7                            -0.005720
# pickup_timezone_evening                     1.000000
# pickup_timezone_late night                 -0.355689
# pickup_timezone_midday                     -0.454350
# pickup_timezone_morning                    -0.327379
# dropoff_timezone_evening                    0.943841
# dropoff_timezone_late night                -0.301404
# dropoff_timezone_midday                    -0.452836
# dropoff_timezone_morning                   -0.317630
#
#                              pickup_timezone_late night  \
# passenger_count                                0.013977
# trip_duration                                 -0.045566
# speed                                          0.018189
# log_distance                                   0.083495
# distance                                       0.054260
# store_and_fwd_flag_N                           0.003119
# store_and_fwd_flag_Y                          -0.003119
# pickup_day_Friday                              0.015827
# pickup_day_Monday                             -0.055803
# pickup_day_Saturday                            0.085197
# pickup_day_Sunday                              0.068472
# pickup_day_Thursday                           -0.023323
# pickup_day_Tuesday                            -0.053162
# pickup_day_Wednesday                          -0.040222
# dropoff_day_Friday                             0.014158
# dropoff_day_Monday                            -0.056374
# dropoff_day_Saturday                           0.085591
# dropoff_day_Sunday                             0.075103
# dropoff_day_Thursday                          -0.026445
# dropoff_day_Tuesday                           -0.053779
# dropoff_day_Wednesday                         -0.041390
# pickup_month_1                                -0.000839
# pickup_month_2                                -0.006166
# pickup_month_3                                -0.008277
# pickup_month_4                                 0.005078
# pickup_month_5                                 0.000210
# pickup_month_6                                 0.010181
# dropoff_month_1                               -0.000990
# dropoff_month_2                               -0.006171
# dropoff_month_3                               -0.008495
# dropoff_month_4                                0.005069
# dropoff_month_5                                0.000422
# dropoff_month_6                                0.010002
# dropoff_month_7                                0.016082
# pickup_timezone_evening                       -0.355689
# pickup_timezone_late night                     1.000000
# pickup_timezone_midday                        -0.318763
# pickup_timezone_morning                       -0.229683
# dropoff_timezone_evening                      -0.355634
# dropoff_timezone_late night                    0.953884
# dropoff_timezone_midday                       -0.317701
# dropoff_timezone_morning                      -0.205414
#
#                              pickup_timezone_midday  pickup_timezone_morning  \
# passenger_count                            0.001713                -0.023606
# trip_duration                              0.063581                -0.036084
# speed                                     -0.017177                 0.010484
# log_distance                              -0.056467                -0.003673
# distance                                  -0.033905                 0.003221
# store_and_fwd_flag_N                      -0.004264                 0.002810
# store_and_fwd_flag_Y                       0.004264                -0.002810
# pickup_day_Friday                         -0.017049                 0.014164
# pickup_day_Monday                          0.004904                 0.027631
# pickup_day_Saturday                       -0.001993                -0.065745
# pickup_day_Sunday                          0.018564                -0.064655
# pickup_day_Thursday                       -0.005224                 0.023825
# pickup_day_Tuesday                         0.002501                 0.034273
# pickup_day_Wednesday                      -0.000314                 0.030890
# dropoff_day_Friday                        -0.016530                 0.014560
# dropoff_day_Monday                         0.005089                 0.027772
# dropoff_day_Saturday                      -0.002127                -0.065829
# dropoff_day_Sunday                         0.016301                -0.065998
# dropoff_day_Thursday                      -0.004239                 0.024577
# dropoff_day_Tuesday                        0.002699                 0.034427
# dropoff_day_Wednesday                      0.000036                 0.031159
# pickup_month_1                             0.001433                -0.003360
# pickup_month_2                             0.002447                -0.002623
# pickup_month_3                            -0.000677                 0.003438
# pickup_month_4                            -0.002893                -0.003286
# pickup_month_5                             0.003262                 0.000627
# pickup_month_6                            -0.003543                 0.005137
# dropoff_month_1                            0.001481                -0.003326
# dropoff_month_2                            0.002452                -0.002619
# dropoff_month_3                           -0.000608                 0.003488
# dropoff_month_4                           -0.002893                -0.003286
# dropoff_month_5                            0.003194                 0.000579
# dropoff_month_6                           -0.003487                 0.005178
# dropoff_month_7                           -0.005126                -0.003694
# pickup_timezone_evening                   -0.454350                -0.327379
# pickup_timezone_late night                -0.318763                -0.229683
# pickup_timezone_midday                     1.000000                -0.293392
# pickup_timezone_morning                   -0.293392                 1.000000
# dropoff_timezone_evening                  -0.395926                -0.327329
# dropoff_timezone_late night               -0.328684                -0.236832
# dropoff_timezone_midday                    0.942458                -0.227646
# dropoff_timezone_morning                  -0.284655                 0.951863
#
#                              dropoff_timezone_evening  \
# passenger_count                              0.005482
# trip_duration                                0.026822
# speed                                       -0.008721
# log_distance                                -0.012942
# distance                                    -0.010799
# store_and_fwd_flag_N                        -0.002380
# store_and_fwd_flag_Y                         0.002380
# pickup_day_Friday                           -0.007886
# pickup_day_Monday                            0.020673
# pickup_day_Saturday                         -0.017917
# pickup_day_Sunday                           -0.020840
# pickup_day_Thursday                          0.003668
# pickup_day_Tuesday                           0.014797
# pickup_day_Wednesday                         0.008546
# dropoff_day_Friday                          -0.007297
# dropoff_day_Monday                           0.020884
# dropoff_day_Saturday                        -0.018063
# dropoff_day_Sunday                          -0.023211
# dropoff_day_Thursday                         0.004781
# dropoff_day_Tuesday                          0.015023
# dropoff_day_Wednesday                        0.008941
# pickup_month_1                               0.002952
# pickup_month_2                               0.004820
# pickup_month_3                               0.005081
# pickup_month_4                               0.000263
# pickup_month_5                              -0.003677
# pickup_month_6                              -0.009546
# dropoff_month_1                              0.003006
# dropoff_month_2                              0.004825
# dropoff_month_3                              0.005159
# dropoff_month_4                              0.000263
# dropoff_month_5                             -0.003752
# dropoff_month_6                             -0.009483
# dropoff_month_7                             -0.005719
# pickup_timezone_evening                      0.943841
# pickup_timezone_late night                  -0.355634
# pickup_timezone_midday                      -0.395926
# pickup_timezone_morning                     -0.327329
# dropoff_timezone_evening                     1.000000
# dropoff_timezone_late night                 -0.366704
# dropoff_timezone_midday                     -0.452767
# dropoff_timezone_morning                    -0.317582
#
#                              dropoff_timezone_late night  \
# passenger_count                                 0.013958
# trip_duration                                  -0.030186
# speed                                           0.017601
# log_distance                                    0.095499
# distance                                        0.065187
# store_and_fwd_flag_N                            0.002758
# store_and_fwd_flag_Y                           -0.002758
# pickup_day_Friday                               0.015578
# pickup_day_Monday                              -0.053801
# pickup_day_Saturday                             0.080426
# pickup_day_Sunday                               0.060706
# pickup_day_Thursday                            -0.018923
# pickup_day_Tuesday                             -0.050403
# pickup_day_Wednesday                           -0.036669
# dropoff_day_Friday                              0.013968
# dropoff_day_Monday                             -0.054375
# dropoff_day_Saturday                            0.080819
# dropoff_day_Sunday                              0.067158
# dropoff_day_Thursday                           -0.021974
# dropoff_day_Tuesday                            -0.051021
# dropoff_day_Wednesday                          -0.037753
# pickup_month_1                                 -0.002426
# pickup_month_2                                 -0.006780
# pickup_month_3                                 -0.008664
# pickup_month_4                                  0.006052
# pickup_month_5                                  0.001036
# pickup_month_6                                  0.010926
# dropoff_month_1                                -0.002573
# dropoff_month_2                                -0.006795
# dropoff_month_3                                -0.008875
# dropoff_month_4                                 0.006052
# dropoff_month_5                                 0.001241
# dropoff_month_6                                 0.010753
# dropoff_month_7                                 0.015597
# pickup_timezone_evening                        -0.301404
# pickup_timezone_late night                      0.953884
# pickup_timezone_midday                         -0.328684
# pickup_timezone_morning                        -0.236832
# dropoff_timezone_evening                       -0.366704
# dropoff_timezone_late night                     1.000000
# dropoff_timezone_midday                        -0.327589
# dropoff_timezone_morning                       -0.229779
#
#                              dropoff_timezone_midday  dropoff_timezone_morning
# passenger_count                             0.001237                 -0.023739
# trip_duration                               0.044705                 -0.055442
# speed                                      -0.017194                  0.012743
# log_distance                               -0.065377                 -0.008485
# distance                                   -0.047066                 -0.000327
# store_and_fwd_flag_N                       -0.002822                  0.003439
# store_and_fwd_flag_Y                        0.002822                 -0.003439
# pickup_day_Friday                          -0.017032                  0.013699
# pickup_day_Monday                           0.006374                  0.024857
# pickup_day_Saturday                        -0.004232                 -0.060095
# pickup_day_Sunday                           0.014259                 -0.057312
# pickup_day_Thursday                        -0.004461                  0.021478
# pickup_day_Tuesday                          0.005096                  0.030155
# pickup_day_Wednesday                        0.001394                  0.027573
# dropoff_day_Friday                         -0.016514                  0.014083
# dropoff_day_Monday                          0.006559                  0.024993
# dropoff_day_Saturday                       -0.004366                 -0.060177
# dropoff_day_Sunday                          0.012019                 -0.058635
# dropoff_day_Thursday                       -0.003478                  0.022205
# dropoff_day_Tuesday                         0.005295                  0.030303
# dropoff_day_Wednesday                       0.001743                  0.027833
# pickup_month_1                              0.000706                 -0.001952
# pickup_month_2                              0.002650                 -0.001927
# pickup_month_3                             -0.000395                  0.003508
# pickup_month_4                             -0.002553                 -0.003848
# pickup_month_5                              0.002766                  0.000170
# pickup_month_6                             -0.003163                  0.004017
# dropoff_month_1                             0.000754                 -0.001919
# dropoff_month_2                             0.002655                 -0.001924
# dropoff_month_3                            -0.000326                  0.003557
# dropoff_month_4                            -0.002553                 -0.003848
# dropoff_month_5                             0.002698                  0.000122
# dropoff_month_6                            -0.003107                  0.004058
# dropoff_month_7                            -0.005109                 -0.003584
# pickup_timezone_evening                    -0.452836                 -0.317630
# pickup_timezone_late night                 -0.317701                 -0.205414
# pickup_timezone_midday                      0.942458                 -0.284655
# pickup_timezone_morning                    -0.227646                  0.951863
# dropoff_timezone_evening                   -0.452767                 -0.317582
# dropoff_timezone_late night                -0.327589                 -0.229779
# dropoff_timezone_midday                     1.000000                 -0.283707
# dropoff_timezone_morning                   -0.283707                  1.000000
#
# [42 rows x 42 columns]

# %%
sns.heatmap(data2.corr())

# %%
base_line_col=['distance']
predictor_cols=['passenger_count','distance','store_and_fwd_flag_N','store_and_fwd_flag_Y',
               'pickup_day_Friday','pickup_day_Monday','pickup_day_Saturday','pickup_day_Sunday',
               'pickup_day_Thursday','pickup_day_Tuesday','pickup_day_Wednesday','dropoff_day_Friday',
               'dropoff_day_Monday','dropoff_day_Saturday','dropoff_day_Sunday','dropoff_day_Thursday',
               'dropoff_day_Tuesday','dropoff_day_Wednesday','pickup_month_1','pickup_month_5','pickup_month_6',
               'dropoff_month_1','dropoff_month_5','dropoff_month_6','pickup_timezone_late night',
               'pickup_timezone_midday','pickup_timezone_morning','dropoff_timezone_evening',
               'dropoff_timezone_late night','dropoff_timezone_midday','dropoff_timezone_morning']
target_col=['trip_duration']

# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score
def modelfit(estimator,data_train,data_test,predictors,target):
    estimator.fit(data_train[predictors], data_train.loc[:,target])
    train_pred=estimator.predict(data_train[predictors])
    cv_score=cross_val_score(estimator,data_train[predictors],data_train.loc[:,target],cv=20,scoring='neg_mean_squared_error')
    
    cv_score=np.sqrt(np.abs(cv_score))
    #Print model report:
    print ("\nModel Report")
    print ("RMSE on Train Data: %.4g" % np.sqrt(metrics.mean_squared_error(data_train.loc[:,target].values, train_pred)))
    print ("CV Score : Mean - %.4g | Std - %.4g | Min - %.4g | Max - %.4g" % (np.mean(cv_score),np.std(cv_score),np.min(cv_score),np.max(cv_score)))
    
    test_pred=estimator.predict(data_test[predictors])
    print ("RMSE on Test Data: %.4g" % np.sqrt(metrics.mean_squared_error(data_test.loc[:,target].values, test_pred)))
    
    
    
    return test_pred

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
validation_size = 0.20
seed = 7
X_train, X_test = train_test_split(data2,test_size=validation_size, random_state=seed)

# %%
mean_pred=np.repeat(X_train[target_col].mean(),len(X_test[target_col]))
from sklearn.metrics import mean_squared_error as mae
sqrt(mae(X_test[target_col],mean_pred))
# Out:
# 664.1583834380903

# %%
alg1 = LinearRegression(normalize=True)
print('The baseline model')
y_pred=modelfit(alg1, X_train, X_test,base_line_col,target_col)
coef1 = alg1.coef_
print('The coeffient is {}'.format(coef1))
# Out:
# The baseline model
#
# Model Report
# RMSE on Train Data: 463
# CV Score : Mean - 461.4 | Std - 47.83 | Min - 420.1 | Max - 592.6
# RMSE on Test Data: 577.6
# The coeffient is [[187.78103658]]

# %%
alg2 = LinearRegression(normalize=True)
y_pred=modelfit(alg2, X_train, X_test, predictor_cols,target_col)
coef1 = pd.Series(alg2.coef_[0], predictor_cols).sort_values()
coef1.plot(kind='bar', title='Model Coefficients')
# Out:
# Model Report
# RMSE on Train Data: 448.7
# CV Score : Mean - 447 | Std - 49.5 | Min - 404.9 | Max - 582.4
# RMSE on Test Data: 567.3
