# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imshow, imread, imsave

# %%
image = imread('Frame0.jpg')

# %%
image.shape
# Out:
# (720, 1280, 3)

# %%
imshow(image)

# %%
print(image)
# Out:
# [[[102 113  34]
#   [ 86  97  19]
#   [ 81  91  18]
#   ...
#   [206 223 251]
#   [206 223 251]
#   [206 223 251]]
#
#  [[100 111  32]
#   [ 86  97  19]
#   [ 82  92  19]
#   ...
#   [206 223 251]
#   [206 223 251]
#   [206 223 251]]
#
#  [[ 97 108  29]
#   [ 85  96  18]
#   [ 85  95  22]
#   ...
#   [206 223 251]
#   [206 223 251]
#   [206 223 251]]
#
#  ...
#
#  [[141 134  44]
#   [151 144  56]
#   [161 154  66]
#   ...
#   [104 118  20]
#   [120 132  30]
#   [140 153  48]]
#
#  [[152 145  55]
#   [159 152  62]
#   [165 158  70]
#   ...
#   [104 118  20]
#   [117 129  29]
#   [135 148  43]]
#
#  [[160 153  62]
#   [165 158  68]
#   [167 160  72]
#   ...
#   [105 119  22]
#   [115 127  27]
#   [131 143  41]]]

# %%
print(image[:,:,1].shape)
# Out:
# (720, 1280)

# %%
print(image[:,:,2].shape)
# Out:
# (720, 1280)

# %%
print('Original Image dimensions are', image.shape)
height, width, channels = image.shape
imshow(image)
# Out:
# Original Image dimensions are (720, 1280, 3)

# %%
from skimage.transform import resize
resized = resize(image,(height/2, width/2))
imshow(resized)

# %%
image = imread('Frame0.jpg')
image.shape
# Out:
# (720, 1280, 3)

# %%
from skimage import color
grayscale_image = color.rgb2gray(image)
grayscale_image.shape
# Out:
# (720, 1280)

# %%
imshow(grayscale_image)

# %%
from skimage import color
image2 = color.gray2rgb(grayscale_image)
red_filter = [1,0,0]
imshow(image2*red_filter)

# %%
image2 = color.gray2rgb(grayscale_image)
green_filter = [0,1,0]
imshow(image2*green_filter)

# %%
image2 = color.gray2rgb(grayscale_image)
blue_filter = [0,0,1]
imshow(image2*blue_filter)
# Out:
# C:\Sandeep\Installations\anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
image2 = color.gray2rgb(grayscale_image)
blue_green_filter = [0,1,1]
imshow(image2*blue_green_filter)

# %%
image2 = color.gray2rgb(grayscale_image)
red_green_filter = [1,1,0]
imshow(image2*red_green_filter)

# %%
from skimage import color
image = imread('Frame0.jpg')
grayscale_image = color.rgb2gray(image)
grayscale_image.shape
# Out:
# (720, 1280)

# %%
new_shape = (grayscale_image.shape[0]*grayscale_image.shape[1])
image2 = np.reshape(grayscale_image, new_shape)
image2.shape
# Out:
# (921600,)

# %%
from skimage.transform import rotate
image = imread('Frame0.jpg')
imshow(image)

# %%
rotated = rotate(image,180,resize=True)
imshow(rotated)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# reading the image
image = imread('Frame0.jpg')

# selecting part of the image only 
cropped1 = image[200:600,200:550]
cropped2 = image[200:450,700:1250]

# plot original and cropped images
imshow(image)
plt.title('Original Image')
# Out:
# Text(0.5, 1, 'Original Image')

# %%
# matplotlib code to display
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(10,10))
ax[0].imshow(cropped1)
ax[0].set_title('Cropped Image')
ax[1].imshow(cropped2)
ax[1].set_title('Cropped Image')
# Out:
# Text(0.5, 1.0, 'Cropped Image')
