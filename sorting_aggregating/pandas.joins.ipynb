# %%
import pandas as pd

# %%
data_frame = pd.DataFrame({
    'roll_no': [102,101,104,103,105],
    'name': ['Aravind','Rahul','Prateek','Piyuesh','Kartik'],
    'grade': ['B','B','A','C','A'],
    'marks':[15,15,20,4,22],
    'city': ['Gurugram','Delhi','Delhi','Gurugram','Hyderabad']
})
data_frame
# Out:
#    roll_no     name grade  marks       city
# 0      102  Aravind     B     15   Gurugram
# 1      101    Rahul     B     15      Delhi
# 2      104  Prateek     A     20      Delhi
# 3      103  Piyuesh     C      4   Gurugram
# 4      105   Kartik     A     22  Hyderabad

# %%
df1 = pd.pivot_table(data_frame, index='grade', values='city', aggfunc='nunique')

# %%
df1.head()
# Out:
#        city  grade
# grade
# A         1      1
# B         1      1
# C         1      1

# %%
city_state_mapping = pd.DataFrame({
    'city': ['Gurugram','Delhi','Hyderabad','Faridabad'],
    'state': ['Haryana','Delhi','Telangana','Haryana']
})

# %%
city_state_mapping
# Out:
#         city      state
# 0   Gurugram    Haryana
# 1      Delhi      Delhi
# 2  Hyderabad  Telangana
# 3  Faridabad    Haryana

# %%
data_frame.merge(city_state_mapping, how='left', on='city')
# Out:
#    roll_no     name grade  marks       city      state
# 0      102  Aravind     B     15   Gurugram    Haryana
# 1      101    Rahul     B     15      Delhi      Delhi
# 2      104  Prateek     A     20      Delhi      Delhi
# 3      103  Piyuesh     C      4   Gurugram    Haryana
# 4      105   Kartik     A     22  Hyderabad  Telangana

# %%
df_roll_no = pd.DataFrame({
    'roll_no': [102,103,109]
})

# %%
df_roll_no
# Out:
#    roll_no
# 0      102
# 1      103
# 2      109

# %%
data_frame.merge(df_roll_no, how='right', on='roll_no')
# Out:
#    roll_no     name grade  marks      city
# 0      102  Aravind     B   15.0  Gurugram
# 1      103  Piyuesh     C    4.0  Gurugram
# 2      109      NaN   NaN    NaN       NaN

# %%
student_selection = pd.DataFrame({
    'roll_no': [102, 105, 109],
    'company': ['ABC','XYZ','ABC'],
    'package (lpa)': [8,14.5,11]
})

# %%
student_selection
# Out:
#    roll_no company  package (lpa)
# 0      102     ABC            8.0
# 1      105     XYZ           14.5
# 2      109     ABC           11.0

# %%
data_frame.merge(student_selection, how='outer')
# Out:
#    roll_no     name grade  marks       city company  package (lpa)
# 0      102  Aravind     B   15.0   Gurugram     ABC            8.0
# 1      101    Rahul     B   15.0      Delhi     NaN            NaN
# 2      104  Prateek     A   20.0      Delhi     NaN            NaN
# 3      103  Piyuesh     C    4.0   Gurugram     NaN            NaN
# 4      105   Kartik     A   22.0  Hyderabad     XYZ           14.5
# 5      109      NaN   NaN    NaN        NaN     ABC           11.0

# %%
data_frame.merge(student_selection, how='inner', on=['roll_no'])
# Out:
#    roll_no     name grade  marks       city company  package (lpa)
# 0      102  Aravind     B     15   Gurugram     ABC            8.0
# 1      105   Kartik     A     22  Hyderabad     XYZ           14.5

# %%
previous_data = pd.read_csv('dataset/csv/concat/outlet_size_concatenated_data.csv')
outlet_data = pd.read_csv('dataset/csv/concat/outlet_data.csv')

# %%
previous_data.shape, outlet_data.shape
# Out:
# ((6113, 9), (7, 4))

# %%
previous_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA03        18.50          Regular         0.045464        Dairy
# 1           FDS46        17.60          Regular         0.047257  Snack Foods
# 2           FDP49         9.00          Regular         0.069089    Breakfast
# 3           FDU02        13.35          Low Fat         0.102492        Dairy
# 4           NCB30        14.60          Low Fat         0.025698    Household
#
#    Item_MRP Outlet_Identifier        Outlet_Type  Item_Outlet_Sales
# 0  144.1102            OUT046  Supermarket Type1          2187.1530
# 1  119.6782            OUT046  Supermarket Type1          2145.2076
# 2   56.3614            OUT046  Supermarket Type1          1547.3192
# 3  230.5352            OUT035  Supermarket Type1          2748.4224
# 4  196.5084            OUT035  Supermarket Type1          1587.2672

# %%
outlet_data
# Out:
#   Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0            OUT013                       1987        High
# 1            OUT018                       2009      Medium
# 2            OUT019                       1985       Small
# 3            OUT027                       1985      Medium
# 4            OUT035                       2004       Small
# 5            OUT046                       1997       Small
# 6            OUT049                       1999      Medium
#
#   Outlet_Location_Type
# 0               Tier 3
# 1               Tier 3
# 2               Tier 1
# 3               Tier 3
# 4               Tier 2
# 5               Tier 1
# 6               Tier 1

# %%
outlet_data.Outlet_Identifier.unique()
# Out:
# array(['OUT013', 'OUT018', 'OUT019', 'OUT027', 'OUT035', 'OUT046',
#        'OUT049'], dtype=object)

# %%
previous_data.merge(outlet_data, how='left', on='Outlet_Identifier')
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA03       18.500          Regular         0.045464
# 1              FDS46       17.600          Regular         0.047257
# 2              FDP49        9.000          Regular         0.069089
# 3              FDU02       13.350          Low Fat         0.102492
# 4              NCB30       14.600          Low Fat         0.025698
# ...              ...          ...              ...              ...
# 6108           FDQ31        5.785          Regular         0.053802
# 6109           FDJ32       10.695          Low Fat         0.057744
# 6110           DRJ49        6.865          Low Fat         0.000000
# 6111           FDR26       20.700          Low Fat         0.042801
# 6112           FDF22        6.865          Low Fat         0.056783
#
#                   Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# ...

# %%
item_data = pd.read_csv('dataset/csv/concat/item_idenifier.csv')

# %%
item_data.head()
# Out:
#   Item_Identifier
# 0           DRI51
# 1           FDL48
# 2           FDL38
# 3           FDF17
# 4           FDN56

# %%
item_data.shape
# Out:
# (100, 1)

# %%
previous_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA03        18.50          Regular         0.045464        Dairy
# 1           FDS46        17.60          Regular         0.047257  Snack Foods
# 2           FDP49         9.00          Regular         0.069089    Breakfast
# 3           FDU02        13.35          Low Fat         0.102492        Dairy
# 4           NCB30        14.60          Low Fat         0.025698    Household
#
#    Item_MRP Outlet_Identifier        Outlet_Type  Item_Outlet_Sales
# 0  144.1102            OUT046  Supermarket Type1          2187.1530
# 1  119.6782            OUT046  Supermarket Type1          2145.2076
# 2   56.3614            OUT046  Supermarket Type1          1547.3192
# 3  230.5352            OUT035  Supermarket Type1          2748.4224
# 4  196.5084            OUT035  Supermarket Type1          1587.2672

# %%
previous_data.merge(item_data, how='right', on='Item_Identifier')
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0             FDB11       16.000          Low Fat         0.060837
# 1             FDB11       16.000          Low Fat         0.060943
# 2             FDB11       16.000               LF         0.060797
# 3             FDX20        7.365          Low Fat         0.042560
# 4             FDX20        7.365          Low Fat         0.042552
# ..              ...          ...              ...              ...
# 417           FDJ07          NaN          Low Fat         0.014354
# 418           FDF17        5.190          Low Fat         0.042687
# 419           FDV08          NaN          Low Fat         0.028456
# 420           FDV08        7.350          Low Fat         0.028711
# 421           FDV08        7.350          Low Fat         0.028571
#
#                  Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0            Starchy Foods  226.8404            OUT035  Supermarket Type1
# ...
