# %%
import pandas as pd

# %%
df_a = pd.DataFrame({
    'subject_id': ['1', '2', '3', '4', '5'],
    'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
    'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']
})
df_a
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches

# %%
df_b = pd.DataFrame({
    'subject_id': ['4', '5', '6', '7', '8'],
    'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
    'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']
})
df_b
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
df_n = pd.DataFrame({
    'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
    'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]
})
df_n
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %%
df_new = pd.concat([df_a, df_b], axis=0)

# %%
df_new
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
pd.merge(df_new, df_n, on='subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15

# %%
pd.merge(df_new, df_n, on='subject_id', how='inner')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15

# %%
pd.merge(df_new, df_n, on='subject_id', how='left')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson     51.0
# 1          2        Amy  Ackerman     15.0
# 2          3      Allen       Ali     15.0
# 3          4      Alice      Aoni     61.0
# 4          5     Ayoung   Atiches     16.0
# 5          4      Billy    Bonder     61.0
# 6          5      Brian     Black     16.0
# 7          6       Bran   Balwner      NaN
# 8          7      Bryce     Brice     14.0
# 9          8      Betty    Btisan     15.0

# %%
pd.merge(df_new, df_n, on='subject_id', how='right')
# Out:
#    subject_id first_name last_name  test_id
# 0           1       Alex  Anderson       51
# 1           2        Amy  Ackerman       15
# 2           3      Allen       Ali       15
# 3           4      Alice      Aoni       61
# 4           4      Billy    Bonder       61
# 5           5     Ayoung   Atiches       16
# 6           5      Brian     Black       16
# 7           7      Bryce     Brice       14
# 8           8      Betty    Btisan       15
# 9           9        NaN       NaN        1
# 10         10        NaN       NaN       61
# 11         11        NaN       NaN       16

# %%
data = pd.read_csv('../dataset/csv/big_mart_sales.csv')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.Item_MRP.count()
# Out:
# 8523

# %%
data.Item_MRP.unique()
# Out:
# array([249.8092,  48.2692, 141.618 , ...,  57.5904, 214.5218,  75.467 ])

# %%
data.Item_MRP.mean()
# Out:
# 140.9927819781768

# %%
data.Item_MRP.median()
# Out:
# 143.0128

# %%
data.Item_MRP.mode()
# Out:
# 0    172.0422
# dtype: float64

# %%
data.Item_Type.mode()
# Out:
# 0    Fruits and Vegetables
# dtype: object

# %%
data.Item_Type.value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
data.Item_MRP.min()
# Out:
# 31.29

# %%
data.Item_MRP.max()
# Out:
# 266.8884

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data.shape
# Out:
# (8523, 12)

# %%
d = data.groupby(['Item_Identifier'])

# %%
len(d.groups)
# Out:
# 1559

# %%
d.groups
# Out:
# {'DRA12': Int64Index([118, 1197, 1245, 1693, 7467, 8043], dtype='int64'),
#  'DRA24': Int64Index([1148, 2879, 4130, 4416, 4900, 6863, 8195], dtype='int64'),
#  'DRA59': Int64Index([1876, 3927, 3962, 5609, 6057, 6179, 6338, 8371], dtype='int64'),
#  'DRB01': Int64Index([3465, 3571, 3733], dtype='int64'),
#  'DRB13': Int64Index([1431, 1836, 2479, 4135, 6626], dtype='int64'),
#  'DRB24': Int64Index([2657, 6128, 7619, 7811], dtype='int64'),
#  'DRB25': Int64Index([776, 2533, 3161, 6058, 8063, 8289], dtype='int64'),
#  'DRB48': Int64Index([103, 458, 576, 1918, 2944, 5627, 8106], dtype='int64'),
#  'DRC01': Int64Index([1, 2272, 2927, 5029, 5077, 5218], dtype='int64'),
#  'DRC12': Int64Index([772, 4605, 7062, 7557], dtype='int64'),
#  'DRC13': Int64Index([1253, 2545, 2878, 5377], dtype='int64'),
#  'DRC24': Int64Index([4353, 7275], dtype='int64'),
#  'DRC25': Int64Index([1708, 2671, 2796, 4276, 6689, 6695, 6719], dtype='int64'),
# ...

# %%
d.mean()
# Out:
#                  Item_Weight  Item_Visibility    Item_MRP  \
# Item_Identifier
# DRA12                 11.600         0.031956  141.865400
# DRA24                 19.350         0.048062  164.086800
# DRA59                  8.270         0.134718  185.179900
# DRB01                  7.390         0.082126  189.586333
# DRB13                  6.115         0.008002  189.693000
# ...                      ...              ...         ...
# NCZ30                  6.590         0.024956  120.752657
# NCZ41                 19.850         0.051623  125.630400
# NCZ42                 10.500         0.009044  236.644800
# NCZ53                  9.600         0.027775  188.321400
# NCZ54                 14.650         0.080426  162.255200
#
#                  Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Identifier
# DRA12                          2001.166667        1843.600200
# DRA24                          1995.000000        2246.218971
# ...

# %%
d.mean()['Item_Weight']
# Out:
# Item_Identifier
# DRA12    11.600
# DRA24    19.350
# DRA59     8.270
# DRB01     7.390
# DRB13     6.115
#           ...
# NCZ30     6.590
# NCZ41    19.850
# NCZ42    10.500
# NCZ53     9.600
# NCZ54    14.650
# Name: Item_Weight, Length: 1559, dtype: float64

# %%
d.sum()['Item_MRP']
# Out:
# Item_Identifier
# DRA12     851.1924
# DRA24    1148.6076
# DRA59    1481.4392
# DRB01     568.7590
# DRB13     948.4650
#            ...
# NCZ30     845.2686
# NCZ41     628.1520
# NCZ42    1183.2240
# NCZ53     941.6070
# NCZ54    1135.7864
# Name: Item_MRP, Length: 1559, dtype: float64

# %%
d.sum()['Item_MRP']
# Out:
# Item_Identifier
# DRA12     851.1924
# DRA24    1148.6076
# DRA59    1481.4392
# DRB01     568.7590
# DRB13     948.4650
#            ...
# NCZ30     845.2686
# NCZ41     628.1520
# NCZ42    1183.2240
# NCZ53     941.6070
# NCZ54    1135.7864
# Name: Item_MRP, Length: 1559, dtype: float64

# %%
d1 = data.groupby(['Outlet_Size', 'Item_Type'])

# %%
d1.groups
# Out:
# {('Medium',
#   'Dairy'): Int64Index([   0,   91,  198,  293,  368,  412,  423,  438,  456,  464,
#              ...
#              8088, 8093, 8103, 8159, 8165, 8168, 8182, 8280, 8306, 8448],
#             dtype='int64', length=218),
#  ('Medium',
#   'Soft Drinks'): Int64Index([   1,   37,  153,  345,  458,  517,  560,  630,  647,  700,
#              ...
#              7952, 7983, 8150, 8190, 8332, 8363, 8418, 8485, 8487, 8506],
#             dtype='int64', length=137),
#  ('Medium',
#   'Meat'): Int64Index([   2,   89,  190,  248,  275,  346,  357,  382,  426,  580,
#              ...
#              8161, 8201, 8234, 8294, 8339, 8349, 8427, 8443, 8470, 8491],
#             dtype='int64', length=149),
#  (nan,
#   'Fruits and Vegetables'): Int64Index([   3,   53,   85,   90,  138,  171,  174,  192,  216,  232,
#              ...
#              8336, 8365, 8393, 8431, 8464, 8468, 8481, 8486, 8508, 8509],
#             dtype='int64', length=349),
#  ('High',
# ...

# %%
d1.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 2011           FDX59       10.195          Low Fat         0.051618
# 4271           FDJ45       17.750          Low Fat         0.073350
# 5785           FDK45       11.650          Low Fat         0.033830
# 7098           FDG33        5.365          Regular         0.140124
# 8075           FDH21       10.395          Low Fat         0.031199
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
d1.first()
# Out:
#                                   Item_Identifier  Item_Weight  \
# Outlet_Size Item_Type
# High        Baking Goods                    FDL12       15.850
#             Breads                          FDU11        4.785
#             Breakfast                       FDO13        7.865
#             Canned                          FDL50       12.150
#             Dairy                           FDU50        5.750
#             Frozen Foods                    FDM40       10.195
#             Fruits and Vegetables           FDF32       16.350
#             Hard Drinks                     DRJ59       11.650
#             Health and Hygiene              NCI17        8.645
#             Household                       NCD19        8.930
#             Meat                            FDK43        9.800
#             Others                          NCK19        9.800
#             Seafood                         FDI57       19.850
# ...

# %%
d1.mean()
# Out:
#                                    Item_Weight  Item_Visibility    Item_MRP  \
# Outlet_Size Item_Type
# High        Baking Goods             12.036918         0.059490  129.202044
#             Breads                   11.048000         0.065586  133.758960
#             Breakfast                12.564231         0.075118  147.490585
#             Canned                   11.922231         0.056733  135.442708
#             Dairy                    13.071875         0.068907  153.509172
#             Frozen Foods             13.250707         0.065639  136.829250
#             Fruits and Vegetables    13.259613         0.061302  145.572870
#             Hard Drinks              11.741957         0.062271  141.927522
#             Health and Hygiene       13.028770         0.051031  135.110980
#             Household                14.033398         0.053742  147.097522
#             Meat                     13.384268         0.055831  137.244790
# ...

# %%
pd.pivot_table(data, index=['Outlet_Size', 'Item_Type'], values='Item_MRP', aggfunc='mean')
# Out:
#                                      Item_MRP
# Outlet_Size Item_Type
# High        Baking Goods           129.202044
#             Breads                 133.758960
#             Breakfast              147.490585
#             Canned                 135.442708
#             Dairy                  153.509172
#             Frozen Foods           136.829250
#             Fruits and Vegetables  145.572870
#             Hard Drinks            141.927522
#             Health and Hygiene     135.110980
#             Household              147.097522
#             Meat                   137.244790
#             Others                 132.576613
#             Seafood                134.864240
#             Snack Foods            145.847086
#             Soft Drinks            131.758473
#             Starchy Foods          158.157074
# Medium      Baking Goods           126.178568
#             Breads                 140.861039
#             Breakfast              134.537511
# ...

# %%
d.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.30          Low Fat         0.016047
# 1              DRC01         5.92          Regular         0.019278
# 2              FDN15        17.50          Low Fat         0.016760
# 3              FDX07        19.20          Regular         0.000000
# 4              NCD19         8.93          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8513           FDH31        12.00          Regular         0.020407
# 8515           FDH24        20.70          Low Fat         0.021518
# 8516           NCJ19        18.60          Low Fat         0.118661
# 8517           FDF53        20.75              reg         0.083607
# 8522           DRG01        14.80          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.shape
# Out:
# (8523, 12)

# %%
d.mean()
# Out:
#                        Item_Weight  Item_Visibility    Item_MRP  \
# Item_Type
# Baking Goods             12.277108         0.069169  126.380766
# Breads                   11.346936         0.066255  140.952669
# Breakfast                12.768202         0.085723  141.788151
# Canned                   12.305705         0.068129  139.763832
# Dairy                    13.426069         0.072427  148.499208
# Frozen Foods             12.867061         0.065645  138.503366
# Fruits and Vegetables    13.224769         0.068513  144.581235
# Hard Drinks              11.400328         0.064943  137.077928
# Health and Hygiene       13.142314         0.055216  130.818921
# Household                13.384736         0.061322  149.424753
# Meat                     12.817344         0.062284  139.882032
# Others                   13.853285         0.060241  132.851430
# Seafood                  12.552843         0.074976  141.841719
# ...

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
   'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
   'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
   'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
   'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)

# %%
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
d = df.groupby('Team')

# %%
d.groups
# Out:
# {'Devils': Int64Index([2, 3], dtype='int64'),
#  'Kings': Int64Index([4, 6, 7], dtype='int64'),
#  'Riders': Int64Index([0, 1, 8, 11], dtype='int64'),
#  'Royals': Int64Index([9, 10], dtype='int64'),
#  'kings': Int64Index([5], dtype='int64')}

# %%
d.head()
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
import pandas as pd

# %%
data = pd.read_csv('../dataset/csv/big_mart_sales.csv')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.groupby(['Item_Identifier'])

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
d1 = data.groupby(['Item_Identifier'])

# %%
d1.groups
# Out:
# {'DRA12': Int64Index([118, 1197, 1245, 1693, 7467, 8043], dtype='int64'),
#  'DRA24': Int64Index([1148, 2879, 4130, 4416, 4900, 6863, 8195], dtype='int64'),
#  'DRA59': Int64Index([1876, 3927, 3962, 5609, 6057, 6179, 6338, 8371], dtype='int64'),
#  'DRB01': Int64Index([3465, 3571, 3733], dtype='int64'),
#  'DRB13': Int64Index([1431, 1836, 2479, 4135, 6626], dtype='int64'),
#  'DRB24': Int64Index([2657, 6128, 7619, 7811], dtype='int64'),
#  'DRB25': Int64Index([776, 2533, 3161, 6058, 8063, 8289], dtype='int64'),
#  'DRB48': Int64Index([103, 458, 576, 1918, 2944, 5627, 8106], dtype='int64'),
#  'DRC01': Int64Index([1, 2272, 2927, 5029, 5077, 5218], dtype='int64'),
#  'DRC12': Int64Index([772, 4605, 7062, 7557], dtype='int64'),
#  'DRC13': Int64Index([1253, 2545, 2878, 5377], dtype='int64'),
#  'DRC24': Int64Index([4353, 7275], dtype='int64'),
#  'DRC25': Int64Index([1708, 2671, 2796, 4276, 6689, 6695, 6719], dtype='int64'),
# ...

# %%
d1.mean()
# Out:
#                  Item_Weight  Item_Visibility    Item_MRP  \
# Item_Identifier
# DRA12                 11.600         0.031956  141.865400
# DRA24                 19.350         0.048062  164.086800
# DRA59                  8.270         0.134718  185.179900
# DRB01                  7.390         0.082126  189.586333
# DRB13                  6.115         0.008002  189.693000
# ...                      ...              ...         ...
# NCZ30                  6.590         0.024956  120.752657
# NCZ41                 19.850         0.051623  125.630400
# NCZ42                 10.500         0.009044  236.644800
# NCZ53                  9.600         0.027775  188.321400
# NCZ54                 14.650         0.080426  162.255200
#
#                  Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Identifier
# DRA12                          2001.166667        1843.600200
# DRA24                          1995.000000        2246.218971
# ...

# %%
data.mean()
# Out:
# Item_Weight                    12.857645
# Item_Visibility                 0.066132
# Item_MRP                      140.992782
# Outlet_Establishment_Year    1997.831867
# Item_Outlet_Sales            2181.288914
# dtype: float64

# %%
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
data.median()
# Out:
# Item_Weight                    12.600000
# Item_Visibility                 0.053931
# Item_MRP                      143.012800
# Outlet_Establishment_Year    1999.000000
# Item_Outlet_Sales            1794.331000
# dtype: float64

# %%
d2 = data.groupby(['Outlet_Size','Item_Type'])

# %%
d2.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 2011           FDX59       10.195          Low Fat         0.051618
# 4271           FDJ45       17.750          Low Fat         0.073350
# 5785           FDK45       11.650          Low Fat         0.033830
# 7098           FDG33        5.365          Regular         0.140124
# 8075           FDH21       10.395          Low Fat         0.031199
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
d2.first()
# Out:
#                                   Item_Identifier  Item_Weight  \
# Outlet_Size Item_Type
# High        Baking Goods                    FDL12       15.850
#             Breads                          FDU11        4.785
#             Breakfast                       FDO13        7.865
#             Canned                          FDL50       12.150
#             Dairy                           FDU50        5.750
#             Frozen Foods                    FDM40       10.195
#             Fruits and Vegetables           FDF32       16.350
#             Hard Drinks                     DRJ59       11.650
#             Health and Hygiene              NCI17        8.645
#             Household                       NCD19        8.930
#             Meat                            FDK43        9.800
#             Others                          NCK19        9.800
#             Seafood                         FDI57       19.850
# ...

# %%
d2.mean()
# Out:
#                                    Item_Weight  Item_Visibility    Item_MRP  \
# Outlet_Size Item_Type
# High        Baking Goods             12.036918         0.059490  129.202044
#             Breads                   11.048000         0.065586  133.758960
#             Breakfast                12.564231         0.075118  147.490585
#             Canned                   11.922231         0.056733  135.442708
#             Dairy                    13.071875         0.068907  153.509172
#             Frozen Foods             13.250707         0.065639  136.829250
#             Fruits and Vegetables    13.259613         0.061302  145.572870
#             Hard Drinks              11.741957         0.062271  141.927522
#             Health and Hygiene       13.028770         0.051031  135.110980
#             Household                14.033398         0.053742  147.097522
#             Meat                     13.384268         0.055831  137.244790
# ...

# %%
d2.mean()['Item_Weight']
# Out:
# Outlet_Size  Item_Type
# High         Baking Goods             12.036918
#              Breads                   11.048000
#              Breakfast                12.564231
#              Canned                   11.922231
#              Dairy                    13.071875
#              Frozen Foods             13.250707
#              Fruits and Vegetables    13.259613
#              Hard Drinks              11.741957
#              Health and Hygiene       13.028770
#              Household                14.033398
#              Meat                     13.384268
#              Others                   14.008437
#              Seafood                  13.002000
#              Snack Foods              13.404560
#              Soft Drinks              12.233776
#              Starchy Foods            13.562632
# Medium       Baking Goods             12.170112
#              Breads                   11.679231
#              Breakfast                11.668800
# ...

# %%
pd.pivot_table(data, index='Item_Type', values='Item_MRP', aggfunc='sum')
# Out:
#                           Item_MRP
# Item_Type
# Baking Goods            81894.7364
# Breads                  35379.1198
# Breakfast               15596.6966
# Canned                  90706.7270
# Dairy                  101276.4596
# Frozen Foods           118558.8814
# Fruits and Vegetables  178124.0810
# Hard Drinks             29334.6766
# Health and Hygiene      68025.8388
# Household              135976.5254
# Meat                    59449.8638
# Others                  22451.8916
# Seafood                  9077.8700
# Snack Foods            175433.9204
# Soft Drinks             58514.1650
# Starchy Foods           21880.0274
