# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings(action='ignore')

# %%
df = pd.read_csv('train.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Shuffling and Creating Train and Test Set

# %%
from sklearn.utils import shuffle

# %%
df = shuffle(df, random_state=42)
div = int(df.shape[0]/4)
train = df.iloc[:3*div+1,:]
test = df.iloc[3*div+1:]
train.shape, test.shape, df.shape
# Out:
# ((667, 12), (224, 12), (891, 12))

# %%
train.head()
# Out:
#      PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 693          694         0       3            Saad, Mr. Khalil    male  25.0
# 382          383         0       3          Tikkanen, Mr. Juho    male  32.0
# 325          326         1       1    Young, Miss. Marie Grice  female  36.0
# 19            20         1       3     Masselmani, Mrs. Fatima  female   NaN
# 713          714         0       3  Larsson, Mr. August Viktor    male  29.0
#
#      SibSp  Parch             Ticket      Fare Cabin Embarked
# 693      0      0               2672    7.2250   NaN        C
# 382      0      0  STON/O 2. 3101293    7.9250   NaN        S
# 325      0      0           PC 17760  135.6333   C32        C
# 19       0      0               2649    7.2250   NaN        C
# 713      0      0               7545    9.4833   NaN        S

# %%
test.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 277          278         0       2
# 849          850         1       1
# 500          501         0       3
# 513          514         1       1
# 752          753         0       3
#
#                                                Name     Sex   Age  SibSp  \
# 277                     Parkes, Mr. Francis "Frank"    male   NaN      0
# 849    Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female   NaN      1
# 500                                Calic, Mr. Petar    male  17.0      0
# 513  Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1
# 752                Vande Velde, Mr. Johannes Joseph    male  33.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 277      0    239853   0.0000   NaN        S
# 849      0     17453  89.1042   C92        C
# 500      0    315086   8.6625   NaN        S
# 513      0  PC 17603  59.4000   NaN        C
# 752      0    345780   9.5000   NaN        S

# %% [markdown]
# # Simple Mode

# %%
test['simple_mode'] = train['Survived'].mode()[0]

# %%
test.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 277          278         0       2
# 849          850         1       1
# 500          501         0       3
# 513          514         1       1
# 752          753         0       3
#
#                                                Name     Sex   Age  SibSp  \
# 277                     Parkes, Mr. Francis "Frank"    male   NaN      0
# 849    Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female   NaN      1
# 500                                Calic, Mr. Petar    male  17.0      0
# 513  Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1
# 752                Vande Velde, Mr. Johannes Joseph    male  33.0      0
#
#      Parch    Ticket     Fare Cabin Embarked  simple_mode  gender_mode
# 277      0    239853   0.0000   NaN        S            0            0
# 849      0     17453  89.1042   C92        C            0            1
# 500      0    315086   8.6625   NaN        S            0            0
# 513      0  PC 17603  59.4000   NaN        C            0            1
# 752      0    345780   9.5000   NaN        S            0            0

# %%
simple_mode_accuracy = accuracy_score(test['Survived'], test['simple_mode'])
simple_mode_accuracy
# Out:
# 0.6116071428571429

# %% [markdown]
# # Mode based on Gender

# %%
gender_mode = pd.crosstab(train['Survived'],train['Sex'])
gender_mode
# Out:
# Sex       female  male
# Survived
# 0             62   350
# 1            169    86

# %%
test['gender_mode'] = test['Survived']
for i in test['Sex'].unique():
    test['gender_mode'][test['Sex']==str(i)] = train['Survived'][train['Sex']==str(i)].mode()[0]

# %%
gender_accuracy = accuracy_score(test['Survived'], test['gender_mode'])
gender_accuracy
# Out:
# 0.8125
